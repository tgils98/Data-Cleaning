# %%
# RUN ONCE AND ONCE ONLY PER SESSION
import dask
from dask.distributed import Client, LocalCluster

try:
    client = Client('127.0.0.1:8786')
except:
    cluster = LocalCluster(scheduler_port=8786)
    client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:8786' processes=4 threads=16, memory=31.73 GiB>

# %%
pip install prophet
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: prophet in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: Cython>=0.22 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (0.29.24)
# Requirement already satisfied: setuptools>=42 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (58.0.4)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: setuptools-git>=1.2 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (1.2)
# Requirement already satisfied: cmdstanpy>=1.0.1 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (1.0.6)
# Requirement already satisfied: holidays>=0.13 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (0.15)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (3.4.3)
# Requirement already satisfied: wheel>=0.37.0 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (0.37.0)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (4.62.3)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (1.23.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from prophet) (1.3.4)
# Requirement already satisfied: ujson in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from cmdstanpy>=1.0.1->prophet) (4.0.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.11)
# Requirement already satisfied: hijri-converter in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from holidays>=0.13->prophet) (2.2.3)
# Requirement already satisfied: korean-lunar-calendar in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from holidays>=0.13->prophet) (0.2.1)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.3)
# Requirement already satisfied: pytz in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2021.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.4)
# Requirement already satisfied: six in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.0.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.4)

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\trainor-gilhamt\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
# Run as is
import pandas as pd
import numpy as np
import datetime
import glob, os
from collections import defaultdict
from multiprocessing import Pool, cpu_count
from functools import partial

from prophet import Prophet
from prophet.plot import plot_plotly, plot_cross_validation_metric
from prophet.make_holidays import make_holidays_df
from prophet.diagnostics import cross_validation, performance_metrics

from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer, LabelEncoder

import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_columns', 50)
pd.set_option('display.precision', 2)
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Change the value in this bit of code "country_name = 'ZA'"
# This should reflect the country you are running the curve for
# Use the Alpha 3 code from this list: https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes

class ProphetPredictions:
    def __init__(self, model, figforecast, figcomponents, dfcrossvalidation, dfperformancemetrics, figcrossvalidation):
        self.model = model
        self.figforecast = figforecast
        self.figcomponents = figcomponents
        self.dfcrossvalidation = dfcrossvalidation
        self.dfperformancemetrics = dfperformancemetrics
        self.figcrossvalidation = figcrossvalidation

    def getmodel(self):
        return self.model


def mapefn(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


def generate_prediction(myhols, dfpredict):
    #mdl = Prophet(seasonality_mode='multiplicative', seasonality_prior_scale=0.5)    
    ## add cap & floor for df & future
    mydf = dfpredict.copy()
    # Box-Cox transformation of Order 0
    mydf['y'] = np.log(1+mydf['y']) #log transform
    mydf['cap'] = mydf['y'].max()
    mydf['floor'] = 1
    
    mdl = Prophet(growth='logistic', changepoint_prior_scale=0.001, holidays=myhols, yearly_seasonality=True).fit(mydf, iter=100)
    
    # Create future dataset & forecast against
    future = mdl.make_future_dataframe(periods=52, freq='W')
    future['cap'] = mydf['y'].max()
    future['floor'] = 1
    #Maybe update hols here?

    # Predict
    forecast = mdl.predict(future)
    
    # Inverse Box-Cox
    forecast['yhat'] = np.exp(forecast['yhat']) - 1
    forecast['trend'] = np.exp(forecast['trend']) - 1

    # print("Calculating MAPE . . .")
    # df_mape = mapefn(dfpredict['y'], forecast['yhat'])

    return forecast  # ,df_mape,



# Use the Alpha 3 code from this list: https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes
def makeprophethols(timesdf, future_periods, date_freq):
    # Make Holidays with bounds
    year_list = [2020, 2021, 2022]
    country_name = 'NLD'
    myhols = make_holidays_df(year_list, country_name)

    # Create all dates
    myidx = timesdf.sort_values()
    myidx = myidx.drop_duplicates()
    firstdate = myidx[0]
    lastdate = myidx[-1]
    future_dates = pd.date_range(start=lastdate, periods=future_periods+1, freq=date_freq)
    future_dates = future_dates[future_dates > lastdate] # Drop start date if equal to lastdate
    myidx = myidx.append(future_dates[:future_periods]) # Return correct number of periods
    lastdate = myidx[-1] # Update last date
    
    # Select only holidays beginning from 7 days prior to start of dataset
    myhols = myhols.loc[myhols['ds'] > (firstdate - pd.offsets.Day(7))]

    # Select only holidays beginning from 7 days prior to start of dataset to ending last date of dataset
    myhols = myhols.loc[(myhols['ds'] > (firstdate - pd.offsets.Day(7))) & (myhols['ds'] <= lastdate)]
    myhols.reset_index(inplace=True, drop=True)

    # Finds the closest date for each holiday that can be found in your current dataset
    for i in range(len(myhols)):
        myhols.loc[i, 'refdate'] = myidx[myidx.get_loc(pd.to_datetime(myhols.loc[i, 'ds']), method='nearest')]


    myhols['datediff'] = myhols['refdate'] - myhols['ds']

    # Additional time delta ensures it runs up to end of month which is needed when forecasting future monthly data
    for i in range(len(myhols)):
        if myhols.loc[i, 'datediff'] >= datetime.timedelta(minutes=0):
            myhols.loc[i, 'upper_window'] = pd.to_timedelta(myhols.loc[i, 'refdate'] - myhols.loc[i, 'ds'])
        else:
            myhols.loc[i, 'upper_window'] = 0

    for i in range(len(myhols)):
        if myhols.loc[i, 'datediff'] < datetime.timedelta(minutes=0):
            myhols.loc[i, 'lower_window'] = pd.to_timedelta(myhols.loc[i, 'refdate'] - myhols.loc[i, 'ds'])
        else:
            myhols.loc[i, 'lower_window'] = 0

    myhols['upper_window'] = pd.to_timedelta(myhols['upper_window']).dt.days
    myhols['lower_window'] = pd.to_timedelta(myhols['lower_window']).dt.days
    myhols.drop(columns=['refdate', 'datediff'], inplace=True)
    # Set window for the future dataframe
    #To be fixed/created. Ignore future timeperiods for now
    return myhols

def generateweeklyaggs(df, valcol, distcol):
    df['val_pp1'] = df[valcol].shift(periods=1)
    df['dist_pp1'] = df[distcol].shift(periods=1)

    df['val_pp2'] = df[valcol].shift(periods=2)
    df['dist_pp2'] = df[distcol].shift(periods=2)

    df['val_pp3'] = df[valcol].shift(periods=3)
    df['dist_pp3'] = df[distcol].shift(periods=3)

    df['val_chg1'] = df[valcol].diff(periods=1)
    df['dist_chg1'] = df[distcol].diff(periods=1)

    df['val_chg2'] = df[valcol].diff(periods=2)
    df['dist_chg2'] = df[distcol].diff(periods=2)

    df['val_chg3'] = df[valcol].diff(periods=3)
    df['dist_chg3'] = df[distcol].diff(periods=3)

    df['val4wk'] = df[valcol].rolling(4).sum()
    df['dist4wk'] = df[distcol].rolling(4).sum()

    df['val_4wkchg1'] = df['val4wk'].diff(periods=1)
    df['dist_4wkchg1'] = df['dist4wk'].diff(periods=1)

    df['val_4wkchg2'] = df['val4wk'].diff(periods=2)
    df['dist_4wkchg2'] = df['dist4wk'].diff(periods=2)

    return df


def outlier_week_check(row, valchg, val_pp):
    ##Returns true if the % change vs. prev week is greater than 100%
    return (abs(row[valchg] / row[val_pp]) // 1) >= 1


def calculatesupplementarymetrics(df, valcol, distcol):
    df['val_chg1_perc'] = df['val_chg1'] / df['val_pp1']
    df['dist_chg1_perc'] = df['dist_chg1'] / df['dist_pp1']

    df['val_chg2_perc'] = df['val_chg2'] / df['val_pp3']
    df['dist_chg2_perc'] = df['dist_chg2'] / df['dist_pp3']

    df['val_4wkchg1_perc'] = df['val_4wkchg1'] / (df['val4wk'] + df['val_4wkchg1'])
    df['dist_4wkchg1_perc'] = df['dist_4wkchg1'] / (df['dist4wk'] + df['dist_4wkchg1'])

    df['val_4wkchg2_perc'] = df['val_4wkchg2'] / (
            df['val4wk'] + df['val_4wkchg1'] + df['val_4wkchg2'])
    df['dist_4wkchg2_perc'] = df['dist_4wkchg2'] / (
            df['dist4wk'] + df['dist_4wkchg1'] + df['dist_4wkchg2'])

    df.replace((np.inf, -np.inf), (0, 0), inplace=True)

    return df


def createfile(df_input, valcol, tdpcol):
    # Drop zero rows to avoid divide by zero errors
    df = df_input.copy()
    df.drop(df[df[valcol] == 0].index, inplace=True)
    df.drop(df[df[tdpcol] <= 0].index, inplace=True)

    df = generateweeklyaggs(df, valcol, tdpcol)
    df = calculatesupplementarymetrics(df, valcol, tdpcol)

    # Remove rows with less than 4weeks prior history
    df.drop(df[df['dist_chg1'].isna()].index, inplace=True)

    df['is_outlier(100%chg)'] = df.apply(outlier_week_check, axis=1, args=('val_chg1', 'val_pp1')).astype('int')
    return df

# %% [markdown]
# Change the name of the two csv files you will load in. First, the sales file/raw data and secondly, the segmentation file saved as a csv

# %%
my_path = r"C:\Users\trainor-gilhamt\Documents\Unilever NL\SoftDrinks\ISD\\"
files_list = glob.glob(my_path+"*.csv")
tt_raw_dict = {}
for f in files_list:
    temp_df = pd.DataFrame()
    temp_df = pd.read_csv(f, dtype={"Barcode":str})
    key_value = f.replace(my_path,"").replace(".csv","")
    temp_df['Region'] = key_value
    tt_raw_dict[key_value] = temp_df
    
#tt_raw_list = pd.concat([pd.read_csv(f, dtype={"Barcode":str}) for f in files_list])
tt_raw_dict.keys()
# Out:
# dict_keys(['C:\\Users\\trainor-gilhamt\\Documents\\Unilever NL\\SoftDrinks\\ISD\\UL_NL_SoftDrinks_Curve_Model_Data_Transformed'])

# %%
tt_raw_orig = pd.concat([tt_raw_dict[f] for f in tt_raw_dict.keys()])
tt_raw_orig.describe()
# Out:
#            UPC_DESC      UNITS  SALES (EUR)        ACV
# count    594,392.00 594,392.00   594,392.00 594,392.00
# mean  46,782,916.95   2,918.96     4,030.34      52.26
# std   25,107,302.03  10,555.18    14,778.94      41.93
# min        6,797.00       0.04         0.01       0.00
# 25%   23,991,688.00      14.00        21.27       3.16
# 50%   53,703,360.00     394.00       509.03      59.68
# 75%   70,136,330.00   2,047.00     2,762.89      96.19
# max   85,360,903.00 609,459.00   740,872.50     100.00

# %%
tt_raw = tt_raw_orig.loc[(tt_raw_orig['ACV'] <= 100) & (tt_raw_orig['ACV'] > 0) & (tt_raw_orig['UNITS'] > 0) & (tt_raw_orig['SALES (EUR)'] > 0)].reset_index(drop=True)
tt_raw.describe()
# Out:
#            UPC_DESC      UNITS  SALES (EUR)        ACV
# count    594,392.00 594,392.00   594,392.00 594,392.00
# mean  46,782,916.95   2,918.96     4,030.34      52.26
# std   25,107,302.03  10,555.18    14,778.94      41.93
# min        6,797.00       0.04         0.01       0.00
# 25%   23,991,688.00      14.00        21.27       3.16
# 50%   53,703,360.00     394.00       509.03      59.68
# 75%   70,136,330.00   2,047.00     2,762.89      96.19
# max   85,360,903.00 609,459.00   740,872.50     100.00

# %%
tt_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594392 entries, 0 to 594391
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   RETAILER     594392 non-null  object
#  1   UPC_DESC     594392 non-null  int64
#  2   WEEK         594392 non-null  object
#  3   UNITS        594392 non-null  float64
#  4   SALES (EUR)  594392 non-null  float64
#  5   ACV          594392 non-null  float64
#  6   Region       594392 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 31.7+ MB

# %%
tt_raw
# Out:
#             RETAILER  UPC_DESC        WEEK  UNITS  SALES (EUR)   ACV  \
# 0       Albert Heijn      7087  2020-11-29   1.00         3.39  0.05
# 1       Albert Heijn      7087  2020-12-13   1.00         3.39  0.06
# 2       Albert Heijn      7087  2021-10-24   1.00         5.25  0.10
# 3       Albert Heijn      7202  2021-08-01   1.00         5.39  0.07
# 4       Albert Heijn      7237  2020-11-22   1.00         0.85  0.04
# ...              ...       ...         ...    ...          ...   ...
# 594387         Vomar  84759825  2022-08-21   4.00         8.07  2.93
# 594388         Vomar  84759825  2022-09-04   1.00         1.34  2.56
# 594389         Vomar  84759825  2022-09-11   3.00         4.04  2.58
# 594390         Vomar  85359716  2022-10-02  39.00        89.54 20.50
# 594391         Vomar  85359716  2022-10-09  25.00        57.57 31.43
#
#                                                    Region
# 0       C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 1       C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 2       C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 3       C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 4       C:\Users\trainor-gilhamt\Documents\Unilever NL...
# ...                                                   ...
# 594387  C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 594388  C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 594389  C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 594390  C:\Users\trainor-gilhamt\Documents\Unilever NL...
# 594391  C:\Users\trainor-gilhamt\Documents\Unilever NL...
#
# [594392 rows x 7 columns]

# %%
tt_raw['RETAILER'].unique()
# Out:
# array(['Albert Heijn', 'Hoogvliet', 'Jumbo', 'Plus', 'Vomar'],
#       dtype=object)

# %%
tt_raw['WEEK'].unique()
# Out:
# array(['2020-11-29', '2020-12-13', '2021-10-24', '2021-08-01',
#        '2020-11-22', '2020-12-20', '2021-01-03', '2021-01-24',
#        '2021-01-31', '2021-03-07', '2021-03-14', '2021-03-21',
#        '2021-03-28', '2021-04-25', '2021-05-16', '2021-06-06',
#        '2021-06-13', '2021-06-20', '2021-06-27', '2021-07-04',
#        '2021-07-11', '2021-07-18', '2021-07-25', '2021-08-08',
#        '2021-08-15', '2021-08-22', '2021-08-29', '2021-09-05',
#        '2021-09-12', '2021-09-26', '2021-10-03', '2021-11-14',
#        '2021-12-12', '2022-01-09', '2022-03-06', '2022-03-27',
#        '2022-05-01', '2022-05-08', '2022-05-15', '2022-05-22',
#        '2022-08-21', '2022-09-18', '2022-08-28', '2020-11-01',
#        '2021-05-09', '2021-10-10', '2021-10-17', '2020-10-11',
#        '2021-01-10', '2021-01-17', '2021-09-19', '2022-04-03',
#        '2020-12-06', '2022-09-25', '2022-10-02', '2022-10-09',
#        '2020-10-18', '2020-10-25', '2020-11-15', '2020-12-27',
#        '2021-02-07', '2021-02-14', '2021-02-21', '2021-02-28',
#        '2021-04-11', '2021-04-18', '2021-05-23', '2021-05-30',
#        '2021-10-31', '2021-11-21', '2021-11-28', '2021-12-05',
#        '2021-12-19', '2021-12-26', '2022-01-02', '2022-01-16',
#        '2022-02-06', '2022-02-13', '2022-03-13', '2022-03-20',
#        '2022-04-10', '2022-04-17', '2022-05-29', '2022-06-05',
#        '2022-06-12', '2022-06-19', '2022-06-26', '2022-07-03',
#        '2022-07-17', '2022-07-24', '2022-08-07', '2022-08-14',
#        '2022-09-04', '2022-09-11', '2020-11-08', '2021-04-04',
#        '2021-05-02', '2021-11-07', '2022-01-30', '2022-02-20',
#        '2022-02-27', '2022-04-24', '2022-07-10', '2022-07-31',
#        '2022-01-23'], dtype=object)

# %%
tt_raw['WEEK'] = pd.to_datetime(tt_raw['WEEK'])
tt_raw['WEEK'].unique()
# Out:
# array(['2020-11-29T00:00:00.000000000', '2020-12-13T00:00:00.000000000',
#        '2021-10-24T00:00:00.000000000', '2021-08-01T00:00:00.000000000',
#        '2020-11-22T00:00:00.000000000', '2020-12-20T00:00:00.000000000',
#        '2021-01-03T00:00:00.000000000', '2021-01-24T00:00:00.000000000',
#        '2021-01-31T00:00:00.000000000', '2021-03-07T00:00:00.000000000',
#        '2021-03-14T00:00:00.000000000', '2021-03-21T00:00:00.000000000',
#        '2021-03-28T00:00:00.000000000', '2021-04-25T00:00:00.000000000',
#        '2021-05-16T00:00:00.000000000', '2021-06-06T00:00:00.000000000',
#        '2021-06-13T00:00:00.000000000', '2021-06-20T00:00:00.000000000',
#        '2021-06-27T00:00:00.000000000', '2021-07-04T00:00:00.000000000',
#        '2021-07-11T00:00:00.000000000', '2021-07-18T00:00:00.000000000',
#        '2021-07-25T00:00:00.000000000', '2021-08-08T00:00:00.000000000',
#        '2021-08-15T00:00:00.000000000', '2021-08-22T00:00:00.000000000',
#        '2021-08-29T00:00:00.000000000', '2021-09-05T00:00:00.000000000',
#        '2021-09-12T00:00:00.000000000', '2021-09-26T00:00:00.000000000',
#        '2021-10-03T00:00:00.000000000', '2021-11-14T00:00:00.000000000',
#        '2021-12-12T00:00:00.000000000', '2022-01-09T00:00:00.000000000',
#        '2022-03-06T00:00:00.000000000', '2022-03-27T00:00:00.000000000',
#        '2022-05-01T00:00:00.000000000', '2022-05-08T00:00:00.000000000',
#        '2022-05-15T00:00:00.000000000', '2022-05-22T00:00:00.000000000',
#        '2022-08-21T00:00:00.000000000', '2022-09-18T00:00:00.000000000',
#        '2022-08-28T00:00:00.000000000', '2020-11-01T00:00:00.000000000',
#        '2021-05-09T00:00:00.000000000', '2021-10-10T00:00:00.000000000',
#        '2021-10-17T00:00:00.000000000', '2020-10-11T00:00:00.000000000',
#        '2021-01-10T00:00:00.000000000', '2021-01-17T00:00:00.000000000',
#        '2021-09-19T00:00:00.000000000', '2022-04-03T00:00:00.000000000',
#        '2020-12-06T00:00:00.000000000', '2022-09-25T00:00:00.000000000',
#        '2022-10-02T00:00:00.000000000', '2022-10-09T00:00:00.000000000',
#        '2020-10-18T00:00:00.000000000', '2020-10-25T00:00:00.000000000',
#        '2020-11-15T00:00:00.000000000', '2020-12-27T00:00:00.000000000',
#        '2021-02-07T00:00:00.000000000', '2021-02-14T00:00:00.000000000',
#        '2021-02-21T00:00:00.000000000', '2021-02-28T00:00:00.000000000',
#        '2021-04-11T00:00:00.000000000', '2021-04-18T00:00:00.000000000',
#        '2021-05-23T00:00:00.000000000', '2021-05-30T00:00:00.000000000',
#        '2021-10-31T00:00:00.000000000', '2021-11-21T00:00:00.000000000',
#        '2021-11-28T00:00:00.000000000', '2021-12-05T00:00:00.000000000',
#        '2021-12-19T00:00:00.000000000', '2021-12-26T00:00:00.000000000',
#        '2022-01-02T00:00:00.000000000', '2022-01-16T00:00:00.000000000',
#        '2022-02-06T00:00:00.000000000', '2022-02-13T00:00:00.000000000',
#        '2022-03-13T00:00:00.000000000', '2022-03-20T00:00:00.000000000',
#        '2022-04-10T00:00:00.000000000', '2022-04-17T00:00:00.000000000',
#        '2022-05-29T00:00:00.000000000', '2022-06-05T00:00:00.000000000',
#        '2022-06-12T00:00:00.000000000', '2022-06-19T00:00:00.000000000',
#        '2022-06-26T00:00:00.000000000', '2022-07-03T00:00:00.000000000',
#        '2022-07-17T00:00:00.000000000', '2022-07-24T00:00:00.000000000',
#        '2022-08-07T00:00:00.000000000', '2022-08-14T00:00:00.000000000',
#        '2022-09-04T00:00:00.000000000', '2022-09-11T00:00:00.000000000',
#        '2020-11-08T00:00:00.000000000', '2021-04-04T00:00:00.000000000',
#        '2021-05-02T00:00:00.000000000', '2021-11-07T00:00:00.000000000',
#        '2022-01-30T00:00:00.000000000', '2022-02-20T00:00:00.000000000',
#        '2022-02-27T00:00:00.000000000', '2022-04-24T00:00:00.000000000',
#        '2022-07-10T00:00:00.000000000', '2022-07-31T00:00:00.000000000',
#        '2022-01-23T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
salesdf_raw = tt_raw[['RETAILER','UPC_DESC','WEEK','UNITS','SALES (EUR)','ACV']].copy()
#salesdf_raw = tt.copy()
salesdf_raw
# Out:
#             RETAILER  UPC_DESC       WEEK  UNITS  SALES (EUR)   ACV
# 0       Albert Heijn      7087 2020-11-29   1.00         3.39  0.05
# 1       Albert Heijn      7087 2020-12-13   1.00         3.39  0.06
# 2       Albert Heijn      7087 2021-10-24   1.00         5.25  0.10
# 3       Albert Heijn      7202 2021-08-01   1.00         5.39  0.07
# 4       Albert Heijn      7237 2020-11-22   1.00         0.85  0.04
# ...              ...       ...        ...    ...          ...   ...
# 594387         Vomar  84759825 2022-08-21   4.00         8.07  2.93
# 594388         Vomar  84759825 2022-09-04   1.00         1.34  2.56
# 594389         Vomar  84759825 2022-09-11   3.00         4.04  2.58
# 594390         Vomar  85359716 2022-10-02  39.00        89.54 20.50
# 594391         Vomar  85359716 2022-10-09  25.00        57.57 31.43
#
# [594392 rows x 6 columns]

# %%
# Load in your data file
#salesdf_raw = pd.read_csv('C:\\Users\\kuria\\Downloads\\Data Transform\\Asahi UK\\HANDS RAWDATA JAN 20.csv', header = 0, thousands = ',', error_bad_lines = True, warn_bad_lines = True)
segdf = pd.read_excel(my_path+'SEG_PL_Template_UL_NL_Soft Drinks_Nov 22.xlsx',  sheet_name = 'seg')
segdf
# Out:
#       UPC_DESC        CATEGORY  \
# 0     63898203  Soft Drinks 22
# 1     63898232  Soft Drinks 22
# 2     42180929  Soft Drinks 22
# 3     62779370  Soft Drinks 22
# 4     71323594  Soft Drinks 22
# ...        ...             ...
# 8499  42589161  Soft Drinks 22
# 8500  42588914  Soft Drinks 22
# 8501  42589278  Soft Drinks 22
# 8502  79548130  Soft Drinks 22
# 8503  14723852  Soft Drinks 22
#
#                                               SEG_DESC  \
# 0                                          AO SEGMENTS
# 1                                          AO SEGMENTS
# 2                                          AO SEGMENTS
# 3                                          AO SEGMENTS
# 4                                          AO SEGMENTS
# ...                                                ...
# 8499                                ENERGY - AO BRANDS
# 8500                                ENERGY - AO BRANDS
# 8501                                ENERGY - AO BRANDS
# 8502  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# 8503  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
#
#                                          SUB_SEG_DESC  BASE_DESC BASE_SIZE  \
# 0                 BITTER LEMON - REGULAR - EIGEN MERK   63898203        X1
# 1                 BITTER LEMON - REGULAR - EIGEN MERK   63898232        X1
# 2     BITTER LEMON - REGULAR - ROYAL CLUB & AO BRANDS   42180929        X1
# 3     BITTER LEMON - REGULAR - ROYAL CLUB & AO BRANDS   62779370        X1
# 4                                BITTER LEMON - LIGHT   71323594        X1
# ...                                               ...        ...       ...
# 8499                                            NOCCO   42589161        X1
# 8500                                            NOCCO   42588914        X1
# 8501                                            NOCCO   42589278        X1
# 8502                       PET MULTISERVE - KZH - SPA   79548130        X6
# 8503                 PET MULTISERVE - KZH - AO BRANDS   14723852        X1
#
#      MANUFACTURER             BRAND   US_UNITS  US_ACV  US_DOLLARS  \
# 0           EIGEN              E.M.  96,617.00    0.11   39,588.81
# 1           EIGEN              E.M. 103,141.00    0.13   42,273.47
# 2        RED_BULL  ORGNCS_BY_RD_BLL        NaN    0.00         NaN
# 3             USD            LONDON  40,336.00    0.03   16,372.08
# 4         VRUMONA        ROYAL_CLUB 747,908.84    0.51  450,486.19
# ...           ...               ...        ...     ...         ...
# 8499        NOCCO             NOCCO        NaN    0.00         NaN
# 8500        NOCCO             NOCCO  30,604.00    0.07   55,567.82
# 8501        NOCCO             NOCCO      27.00    0.00       61.76
# 8502       SPADEL               SPA     123.00    0.00    1,069.02
# 8503      VRUMONA            SOURCY        NaN    0.00         NaN
#
#                         ProductDescription FRISDRANKEN_NAAR_SORT_VARI_LEVEL_0  \
# 0          E.M. BITTER_LE KZH REG. 250_ML                    TOT. FRISDRANKEN
# 1             E.M. GINGER KZH REG. 250_ML                    TOT. FRISDRANKEN
# 2     ORGNCS_BY BITTER_LE KZH REG. 250_ML                    TOT. FRISDRANKEN
# 3        LONDON BITTER_LE KZH REG. 250_ML                    TOT. FRISDRANKEN
# 4     ROYAL_CLU BITTER_LE KZH LIGH 250_ML                    TOT. FRISDRANKEN
# ...                                    ...                                ...
# 8499           NOCCO PEER KZH LIGH 330_ML                    TOT. FRISDRANKEN
# 8500         NOCCO PERZIK KZH LIGH 330_ML                    TOT. FRISDRANKEN
# 8501       NOCCO TROPICAL KZH LIGH 330_ML                    TOT. FRISDRANKEN
# 8502         SPA CITR KZH REG. 7500_ML_6_                    TOT. FRISDRANKEN
# 8503         SOURCY CITR KZH REG. 1500_ML                    TOT. FRISDRANKEN
#
#          SUBSOORT VERPAKKINGSVORM  BASISINHOUD  ProductAttribute5  \
# 0      BITTER_LEM            BLIK          250                NaN
# 1      BITTER_LEM            BLIK          250                NaN
# 2      BITTER_LEM            BLIK          250                NaN
# 3      BITTER_LEM            BLIK          250                NaN
# 4      BITTER_LEM            BLIK          250                NaN
# ...           ...             ...          ...                ...
# 8499       ENERGY            BLIK          330                NaN
# 8500       ENERGY            BLIK          330                NaN
# 8501       ENERGY            BLIK          330                NaN
# 8502  MIN.W.CITR.      FLES_GROOT         1250                NaN
# 8503  MIN.W.CITR.      FLES_GROOT         1500                NaN
#
#       ProductAttribute6  ProductAttribute7  ProductAttribute8  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 8499                NaN                NaN                NaN
# 8500                NaN                NaN                NaN
# 8501                NaN                NaN                NaN
# 8502                NaN                NaN                NaN
# 8503                NaN                NaN                NaN
#
#       ProductAttribute9  ProductAttribute10  ProductAttribute11  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ...                 ...                 ...                 ...
# 8499                NaN                 NaN                 NaN
# 8500                NaN                 NaN                 NaN
# 8501                NaN                 NaN                 NaN
# 8502                NaN                 NaN                 NaN
# 8503                NaN                 NaN                 NaN
#
#       ProductAttribute12  ProductAttribute13  ProductAttribute14  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 8499                 NaN                 NaN                 NaN
# 8500                 NaN                 NaN                 NaN
# 8501                 NaN                 NaN                 NaN
# 8502                 NaN                 NaN                 NaN
# 8503                 NaN                 NaN                 NaN
#
#       ProductAttribute15  ProductAttribute16  ProductAttribute17  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 8499                 NaN                 NaN                 NaN
# 8500                 NaN                 NaN                 NaN
# 8501                 NaN                 NaN                 NaN
# 8502                 NaN                 NaN                 NaN
# 8503                 NaN                 NaN                 NaN
#
#       ProductAttribute18  ProductAttribute19  ProductAttribute20
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 8499                 NaN                 NaN                 NaN
# 8500                 NaN                 NaN                 NaN
# 8501                 NaN                 NaN                 NaN
# 8502                 NaN                 NaN                 NaN
# 8503                 NaN                 NaN                 NaN
#
# [8504 rows x 32 columns]

# %%
# Run as is
segdf.columns
# Out:
# Index(['UPC_DESC', 'CATEGORY', 'SEG_DESC', 'SUB_SEG_DESC', 'BASE_DESC',
#        'BASE_SIZE', 'MANUFACTURER', 'BRAND', 'US_UNITS', 'US_ACV',
#        'US_DOLLARS', 'ProductDescription',
#        'FRISDRANKEN_NAAR_SORT_VARI_LEVEL_0', 'SUBSOORT', 'VERPAKKINGSVORM',
#        'BASISINHOUD', 'ProductAttribute5', 'ProductAttribute6',
#        'ProductAttribute7', 'ProductAttribute8', 'ProductAttribute9',
#        'ProductAttribute10', 'ProductAttribute11', 'ProductAttribute12',
#        'ProductAttribute13', 'ProductAttribute14', 'ProductAttribute15',
#        'ProductAttribute16', 'ProductAttribute17', 'ProductAttribute18',
#        'ProductAttribute19', 'ProductAttribute20'],
#       dtype='object')

# %% [markdown]
# Edit the left hand side of the colon which should match the list of columns above
#
# Ensure you replace "Barcode" below with the name of your UPC column as per above and so on

# %%
# optional
segdf.rename(columns={'UPC_DESC': 'UPC',
                     }, inplace=True)

# %% [markdown]
# Ensure the output of the table below:
#
# 1) Has data that is in line with your expectations e.g. Mean & Standard Deviation
#
# 2) Has combined both raw sales data & segmentation data files

# %%
salesdf_raw.describe()
# Out:
#            UPC_DESC      UNITS  SALES (EUR)        ACV
# count    594,392.00 594,392.00   594,392.00 594,392.00
# mean  46,782,916.95   2,918.96     4,030.34      52.26
# std   25,107,302.03  10,555.18    14,778.94      41.93
# min        6,797.00       0.04         0.01       0.00
# 25%   23,991,688.00      14.00        21.27       3.16
# 50%   53,703,360.00     394.00       509.03      59.68
# 75%   70,136,330.00   2,047.00     2,762.89      96.19
# max   85,360,903.00 609,459.00   740,872.50     100.00

# %% [markdown]
# If your file has multiple values OR Units columns e.g. Base & Total, drop the type you don't need
#
# The code below drops the Total type as the base column has sufficient rows & correct info to use instead of the totals
#
# Replace UNITS, DOLLARS with the name of the columns you will drop

# %%
# Run as is
salesdf_raw.columns
# Out:
# Index(['RETAILER', 'UPC_DESC', 'WEEK', 'UNITS', 'SALES (EUR)', 'ACV'], dtype='object')

# %%
# If you do have extra columns to drop, uncomment the line below and run
#salesdf_raw.drop(columns=['Product_Description','MARKET'], inplace=True)
#salesdf_raw.drop(columns=['WEEK'], inplace=True)

# %% [markdown]
# Ensure you replace "BASE_UNITS" with the name of your Units column as per above and so on where needed
# Only edit the left hand side of the colon which should match the list of columns above

# %%
salesdf = salesdf_raw.rename(columns={'WEEK':'ds', 
                                      'UPC_DESC': 'UPC',
                                      'RETAILER':'Retailer',
                                      'UNITS':'UNITS',
                                      'SALES (EUR)':'VALUE',
                                      'ACV':'ACV'
                                     }
                            )

# Ensures matches will work as expected via string matching
salesdf['UPC'] = salesdf['UPC'].astype(str)
segdf['UPC'] = segdf['UPC'].astype(str)

salesdf = salesdf.merge(segdf, on='UPC')
# Find all non-UPC seg columns and rename them
for col in salesdf.columns[salesdf.columns.isin(segdf.columns[~segdf.columns.str.contains('UPC')])]:
    salesdf.rename(columns = {col: col+'_ATTRIBUTE'}, inplace=True)
    
salesdf
# Out:
#             Retailer       UPC         ds    UNITS    VALUE   ACV  \
# 0       Albert Heijn      7087 2020-11-29     1.00     3.39  0.05
# 1       Albert Heijn      7087 2020-12-13     1.00     3.39  0.06
# 2       Albert Heijn      7087 2021-10-24     1.00     5.25  0.10
# 3       Albert Heijn      7202 2021-08-01     1.00     5.39  0.07
# 4       Albert Heijn      7237 2020-11-22     1.00     0.85  0.04
# ...              ...       ...        ...      ...      ...   ...
# 593089         Vomar  83212213 2022-09-11   982.00   971.98 98.78
# 593090         Vomar  83212213 2022-09-18   973.00   963.17 97.49
# 593091         Vomar  83212213 2022-09-25 1,016.00 1,005.54 97.35
# 593092         Vomar  83212213 2022-10-02 1,076.00 1,065.04 98.57
# 593093         Vomar  83212213 2022-10-09 1,054.00 1,042.96 98.54
#
#        CATEGORY_ATTRIBUTE                                SEG_DESC_ATTRIBUTE  \
# 0          Soft Drinks 22  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# 1          Soft Drinks 22  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# 2          Soft Drinks 22  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# 3          Soft Drinks 22  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# 4          Soft Drinks 22  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS
# ...                   ...                                               ...
# 593089     Soft Drinks 22                        VRUCHTENDRANK - EIGEN MERK
# 593090     Soft Drinks 22                        VRUCHTENDRANK - EIGEN MERK
# 593091     Soft Drinks 22                        VRUCHTENDRANK - EIGEN MERK
# 593092     Soft Drinks 22                        VRUCHTENDRANK - EIGEN MERK
# 593093     Soft Drinks 22                        VRUCHTENDRANK - EIGEN MERK
#
#                   SUB_SEG_DESC_ATTRIBUTE  BASE_DESC_ATTRIBUTE  \
# 0       PET MULTISERVE - KZH - AO BRANDS                 7087
# 1       PET MULTISERVE - KZH - AO BRANDS                 7087
# 2       PET MULTISERVE - KZH - AO BRANDS                 7087
# 3             PET MULTISERVE - KZH - SPA                 7202
# 4             PET MULTISERVE - KZH - SPA                 7237
# ...                                  ...                  ...
# 593089                    PET MULTISERVE             83212213
# 593090                    PET MULTISERVE             83212213
# 593091                    PET MULTISERVE             83212213
# 593092                    PET MULTISERVE             83212213
# 593093                    PET MULTISERVE             83212213
#
#        BASE_SIZE_ATTRIBUTE MANUFACTURER_ATTRIBUTE BRAND_ATTRIBUTE  \
# 0                       X6                 SPADEL             BRU
# 1                       X6                 SPADEL             BRU
# 2                       X6                 SPADEL             BRU
# 3                       X6                 SPADEL             SPA
# 4                       X1                 SPADEL             SPA
# ...                    ...                    ...             ...
# 593089                  X1                  EIGEN            E.M.
# 593090                  X1                  EIGEN            E.M.
# 593091                  X1                  EIGEN            E.M.
# 593092                  X1                  EIGEN            E.M.
# 593093                  X1                  EIGEN            E.M.
#
#         US_UNITS_ATTRIBUTE  US_ACV_ATTRIBUTE  US_DOLLARS_ATTRIBUTE  \
# 0                     1.00              0.00                  5.25
# 1                     1.00              0.00                  5.25
# 2                     1.00              0.00                  5.25
# 3                      NaN              0.00                   NaN
# 4                 5,250.00              0.01              5,544.43
# ...                    ...               ...                   ...
# 593089           21,672.44              0.02             24,040.16
# 593090           21,672.44              0.02             24,040.16
# 593091           21,672.44              0.02             24,040.16
# 593092           21,672.44              0.02             24,040.16
# 593093           21,672.44              0.02             24,040.16
#
#             ProductDescription_ATTRIBUTE  \
# 0       BRU N.SMAAK KZH MIN. 7500_ML_6_
# 1       BRU N.SMAAK KZH MIN. 7500_ML_6_
# 2       BRU N.SMAAK KZH MIN. 7500_ML_6_
# 3       SPA N.SMAAK KZH MIN. 9000_ML_6_
# 4          SPA N.SMAAK KZH MIN. 1500_ML
# ...                                  ...
# 593089      E.M. APP_CTR_G N.DR 1000_ML
# 593090      E.M. APP_CTR_G N.DR 1000_ML
# 593091      E.M. APP_CTR_G N.DR 1000_ML
# 593092      E.M. APP_CTR_G N.DR 1000_ML
# 593093      E.M. APP_CTR_G N.DR 1000_ML
#
#        FRISDRANKEN_NAAR_SORT_VARI_LEVEL_0_ATTRIBUTE SUBSOORT_ATTRIBUTE  \
# 0                                  TOT. FRISDRANKEN      MINERAALWATER
# 1                                  TOT. FRISDRANKEN      MINERAALWATER
# 2                                  TOT. FRISDRANKEN      MINERAALWATER
# 3                                  TOT. FRISDRANKEN      MINERAALWATER
# 4                                  TOT. FRISDRANKEN      MINERAALWATER
# ...                                             ...                ...
# 593089                             TOT. FRISDRANKEN      VRUCHTENDRANK
# 593090                             TOT. FRISDRANKEN      VRUCHTENDRANK
# 593091                             TOT. FRISDRANKEN      VRUCHTENDRANK
# 593092                             TOT. FRISDRANKEN      VRUCHTENDRANK
# 593093                             TOT. FRISDRANKEN      VRUCHTENDRANK
#
#        VERPAKKINGSVORM_ATTRIBUTE  BASISINHOUD_ATTRIBUTE  \
# 0                     FLES_GROOT                   1250
# 1                     FLES_GROOT                   1250
# 2                     FLES_GROOT                   1250
# 3                     FLES_GROOT                   1500
# 4                     FLES_GROOT                   1500
# ...                          ...                    ...
# 593089                FLES_GROOT                   1000
# 593090                FLES_GROOT                   1000
# 593091                FLES_GROOT                   1000
# 593092                FLES_GROOT                   1000
# 593093                FLES_GROOT                   1000
#
#         ProductAttribute5_ATTRIBUTE  ProductAttribute6_ATTRIBUTE  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 593089                          NaN                          NaN
# 593090                          NaN                          NaN
# 593091                          NaN                          NaN
# 593092                          NaN                          NaN
# 593093                          NaN                          NaN
#
#         ProductAttribute7_ATTRIBUTE  ProductAttribute8_ATTRIBUTE  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 593089                          NaN                          NaN
# 593090                          NaN                          NaN
# 593091                          NaN                          NaN
# 593092                          NaN                          NaN
# 593093                          NaN                          NaN
#
#         ProductAttribute9_ATTRIBUTE  ProductAttribute10_ATTRIBUTE  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 593089                          NaN                           NaN
# 593090                          NaN                           NaN
# 593091                          NaN                           NaN
# 593092                          NaN                           NaN
# 593093                          NaN                           NaN
#
#         ProductAttribute11_ATTRIBUTE  ProductAttribute12_ATTRIBUTE  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 593089                           NaN                           NaN
# 593090                           NaN                           NaN
# 593091                           NaN                           NaN
# 593092                           NaN                           NaN
# 593093                           NaN                           NaN
#
#         ProductAttribute13_ATTRIBUTE  ProductAttribute14_ATTRIBUTE  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 593089                           NaN                           NaN
# 593090                           NaN                           NaN
# 593091                           NaN                           NaN
# 593092                           NaN                           NaN
# 593093                           NaN                           NaN
#
#         ProductAttribute15_ATTRIBUTE  ProductAttribute16_ATTRIBUTE  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 593089                           NaN                           NaN
# 593090                           NaN                           NaN
# 593091                           NaN                           NaN
# 593092                           NaN                           NaN
# 593093                           NaN                           NaN
#
#         ProductAttribute17_ATTRIBUTE  ProductAttribute18_ATTRIBUTE  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 593089                           NaN                           NaN
# 593090                           NaN                           NaN
# 593091                           NaN                           NaN
# 593092                           NaN                           NaN
# 593093                           NaN                           NaN
#
#         ProductAttribute19_ATTRIBUTE  ProductAttribute20_ATTRIBUTE
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 593089                           NaN                           NaN
# 593090                           NaN                           NaN
# 593091                           NaN                           NaN
# 593092                           NaN                           NaN
# 593093                           NaN                           NaN
#
# [593094 rows x 37 columns]

# %% [markdown]
# Fill in the two variables below (ANALYSIS_CATEGORY & FOCUS_ATTRIBUTE_COLUMN) with the appropriate value

# %%
salesdf.columns
# Out:
# Index(['Retailer', 'UPC', 'ds', 'UNITS', 'VALUE', 'ACV', 'CATEGORY_ATTRIBUTE',
#        'SEG_DESC_ATTRIBUTE', 'SUB_SEG_DESC_ATTRIBUTE', 'BASE_DESC_ATTRIBUTE',
#        'BASE_SIZE_ATTRIBUTE', 'MANUFACTURER_ATTRIBUTE', 'BRAND_ATTRIBUTE',
#        'US_UNITS_ATTRIBUTE', 'US_ACV_ATTRIBUTE', 'US_DOLLARS_ATTRIBUTE',
#        'ProductDescription_ATTRIBUTE',
#        'FRISDRANKEN_NAAR_SORT_VARI_LEVEL_0_ATTRIBUTE', 'SUBSOORT_ATTRIBUTE',
#        'VERPAKKINGSVORM_ATTRIBUTE', 'BASISINHOUD_ATTRIBUTE',
#        'ProductAttribute5_ATTRIBUTE', 'ProductAttribute6_ATTRIBUTE',
#        'ProductAttribute7_ATTRIBUTE', 'ProductAttribute8_ATTRIBUTE',
#        'ProductAttribute9_ATTRIBUTE', 'ProductAttribute10_ATTRIBUTE',
#        'ProductAttribute11_ATTRIBUTE', 'ProductAttribute12_ATTRIBUTE',
#        'ProductAttribute13_ATTRIBUTE', 'ProductAttribute14_ATTRIBUTE',
#        'ProductAttribute15_ATTRIBUTE', 'ProductAttribute16_ATTRIBUTE',
#        'ProductAttribute17_ATTRIBUTE', 'ProductAttribute18_ATTRIBUTE',
#        'ProductAttribute19_ATTRIBUTE', 'ProductAttribute20_ATTRIBUTE'],
#       dtype='object')

# %%
# This is the name of your category & name-prefix of the output files
ANALYSIS_CATEGORY = 'UL_NL_SD_ISD'
# This is the attribute you are creating an attribute specific curve for
# If you're running ISD, it is usually SEG_DESC_ATTRIBUTE
FOCUS_ATTRIBUTE_COLUMN = 'SEG_DESC_ATTRIBUTE'

print(f"There are {salesdf[FOCUS_ATTRIBUTE_COLUMN].nunique()} unique values in {FOCUS_ATTRIBUTE_COLUMN}\n The relative shares are as below:")
salesdf[[FOCUS_ATTRIBUTE_COLUMN, 'VALUE']].groupby(FOCUS_ATTRIBUTE_COLUMN).sum()/salesdf['VALUE'].sum()
# Out:
# There are 43 unique values in SEG_DESC_ATTRIBUTE
#  The relative shares are as below:
#                                                   VALUE
# SEG_DESC_ATTRIBUTE
# AO SEGMENTS                                        0.01
# COLA - LIGHT - COCA COLA & AO BRANDS               0.02
# COLA - LIGHT - EIGEN MERK                          0.02
# COLA - LIGHT - PEPSI                               0.02
# COLA - REGULAR - COCA COLA                         0.12
# COLA - REGULAR - EIGEN MERK                        0.02
# COLA - REGULAR - PEPSI & AO BRANDS                 0.01
# COLA - ZERO - COCA COLA                            0.09
# ENERGY - AO BRANDS                                 0.06
# ENERGY - RED BULL                                  0.10
# ICE_TEA_BLACK - CAN                                0.01
# ICE_TEA_BLACK - CARTON                             0.01
# ICE_TEA_BLACK - PET MULTISERVE                     0.01
# ICE_TEA_BLACK - PET SINGLESERVE                    0.01
# ICE_TEA_GREEN - CAN                                0.01
# ICE_TEA_GREEN - CARTON                             0.03
# ICE_TEA_GREEN - PET MULTISERVE                     0.01
# ICE_TEA_GREEN - PET SINGLESERVE                    0.01
# LEMON_LIME                                         0.02
# MINERAALWATER - PET MULTISERVE & AO PACK FORMATS   0.05
# MINERAALWATER - PET SINGLESERVE                    0.05
# ORANGE                                             0.06
# OV.GAZEUSES - LIGHT - AO BRANDS                    0.00
# OV.GAZEUSES - LIGHT - CRYSTAL CL                   0.02
# OV.GAZEUSES - LIGHT - EIGEN MERK                   0.01
# OV.GAZEUSES - LIGHT - SPA                          0.01
# OV.GAZEUSES - REGULAR - AO BRANDS                  0.02
# OV.GAZEUSES - REGULAR - FERNANDES                  0.01
# OV.GAZEUSES - REGULAR - RIVELLA                    0.01
# OV.VRUCHT.LIM. - LIGHT                             0.02
# OV.VRUCHT.LIM. - REGULAR - AO BRANDS               0.03
# OV.VRUCHT.LIM. - REGULAR - EIGEN MERK              0.01
# OV.VRUCHT.LIM. - REGULAR - HERO                    0.01
# OV.VRUCHT.LIM. - REGULAR - SPA                     0.01
# SPORT                                              0.01
# TONIC                                              0.01
# VRUCHT.LIM. - LIGHT                                0.01
# VRUCHT.LIM. - REGULAR - AO BRANDS                  0.02
# VRUCHT.LIM. - REGULAR - DUBBEL FRISS               0.02
# VRUCHT.LIM. - REGULAR - ROOSVICEE                  0.01
# VRUCHTENDRANK - AO BRANDS                          0.01
# VRUCHTENDRANK - APPELSIENTJE                       0.01
# VRUCHTENDRANK - EIGEN MERK                         0.01

# %%
# Run as is
# This creates the working dataframe & deletes rows with NA values
forecastdf = salesdf[[FOCUS_ATTRIBUTE_COLUMN,'Retailer','ds','UNITS','VALUE','ACV']].groupby([FOCUS_ATTRIBUTE_COLUMN,'Retailer','ds']).sum().rename(
    columns={'UNITS':'y'}).reset_index()

prev_row_cnt = forecastdf.shape[0]
forecastdf.dropna(subset=['y'], inplace=True) # Drop NAs
forecastdf = forecastdf.loc[forecastdf['y'] > 0] # Select strictly positive, non-zero values

"""
# Delete attribute-markets with low support = less than 50 rows by market & attribute 
# This is fine to ignore for now as e.g. Herbs will have representation in other markets
rowcounts = forecastdf.groupby([FOCUS_ATTRIBUTE_COLUMN,'MARKET']).count().reset_index()
rows_to_delist = rowcounts.loc[rowcounts['y'] < 52,[FOCUS_ATTRIBUTE_COLUMN,'MARKET']]
# Convert to str then join & select rows not matching rows_to_delist
forecastdf = forecastdf.loc[~(forecastdf[FOCUS_ATTRIBUTE_COLUMN].astype(str) + forecastdf['MARKET'].astype(str)).isin(
    rows_to_delist[FOCUS_ATTRIBUTE_COLUMN].astype(str) + rows_to_delist['MARKET'].astype(str))]
"""
current_row_cnt = forecastdf.shape[0]

print(f'Dropped {current_row_cnt - prev_row_cnt} rows with NA values. Final dataset has {current_row_cnt} rows')
# Out:
# Dropped 0 rows with NA values. Final dataset has 22568 rows

# %%
# Run as is
# Summary of the data rows by market & unique time
attr_sparsity_report = forecastdf[['Retailer','ds',FOCUS_ATTRIBUTE_COLUMN]].groupby(['Retailer',FOCUS_ATTRIBUTE_COLUMN]).count().reset_index().pivot(
    index='Retailer', columns=FOCUS_ATTRIBUTE_COLUMN, values='ds')

num_unique_timeperiods = forecastdf['ds'].nunique()
for col in attr_sparsity_report.columns:
    attr_sparsity_report[col] = attr_sparsity_report[col]/num_unique_timeperiods

#attr_sparsity_report.to_excel('./attr_sparsity_report_'+FOCUS_ATTRIBUTE_COLUMN+'.xlsx')
attr_sparsity_report.describe()
# Out:
# SEG_DESC_ATTRIBUTE  AO SEGMENTS  COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                      5.00                                  5.00
# mean                       1.00                                  1.00
# std                        0.00                                  0.00
# min                        1.00                                  1.00
# 25%                        1.00                                  1.00
# 50%                        1.00                                  1.00
# 75%                        1.00                                  1.00
# max                        1.00                                  1.00
#
# SEG_DESC_ATTRIBUTE  COLA - LIGHT - EIGEN MERK  COLA - LIGHT - PEPSI  \
# count                                    5.00                  5.00
# mean                                     1.00                  1.00
# std                                      0.00                  0.00
# min                                      1.00                  1.00
# 25%                                      1.00                  1.00
# 50%                                      1.00                  1.00
# 75%                                      1.00                  1.00
# max                                      1.00                  1.00
#
# SEG_DESC_ATTRIBUTE  COLA - REGULAR - COCA COLA  COLA - REGULAR - EIGEN MERK  \
# count                                     5.00                         5.00
# mean                                      1.00                         1.00
# std                                       0.00                         0.00
# min                                       1.00                         1.00
# 25%                                       1.00                         1.00
# 50%                                       1.00                         1.00
# 75%                                       1.00                         1.00
# max                                       1.00                         1.00
#
# SEG_DESC_ATTRIBUTE  COLA - REGULAR - PEPSI & AO BRANDS  \
# count                                             5.00
# mean                                              1.00
# std                                               0.00
# min                                               1.00
# 25%                                               1.00
# 50%                                               1.00
# 75%                                               1.00
# max                                               1.00
#
# SEG_DESC_ATTRIBUTE  COLA - ZERO - COCA COLA  ENERGY - AO BRANDS  \
# count                                  5.00                5.00
# mean                                   1.00                1.00
# std                                    0.00                0.00
# min                                    1.00                1.00
# 25%                                    1.00                1.00
# 50%                                    1.00                1.00
# 75%                                    1.00                1.00
# max                                    1.00                1.00
#
# SEG_DESC_ATTRIBUTE  ENERGY - RED BULL  ICE_TEA_BLACK - CAN  \
# count                            5.00                 5.00
# mean                             1.00                 1.00
# std                              0.00                 0.00
# min                              1.00                 1.00
# 25%                              1.00                 1.00
# 50%                              1.00                 1.00
# 75%                              1.00                 1.00
# max                              1.00                 1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_BLACK - CARTON  ICE_TEA_BLACK - PET MULTISERVE  \
# count                                 5.00                            5.00
# mean                                  1.00                            1.00
# std                                   0.00                            0.00
# min                                   1.00                            1.00
# 25%                                   1.00                            1.00
# 50%                                   1.00                            1.00
# 75%                                   1.00                            1.00
# max                                   1.00                            1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_BLACK - PET SINGLESERVE  ICE_TEA_GREEN - CAN  \
# count                                          5.00                 5.00
# mean                                           1.00                 1.00
# std                                            0.00                 0.00
# min                                            1.00                 1.00
# 25%                                            1.00                 1.00
# 50%                                            1.00                 1.00
# 75%                                            1.00                 1.00
# max                                            1.00                 1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_GREEN - CARTON  ICE_TEA_GREEN - PET MULTISERVE  \
# count                                 5.00                            5.00
# mean                                  1.00                            1.00
# std                                   0.00                            0.00
# min                                   1.00                            1.00
# 25%                                   1.00                            1.00
# 50%                                   1.00                            1.00
# 75%                                   1.00                            1.00
# max                                   1.00                            1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_GREEN - PET SINGLESERVE  LEMON_LIME  \
# count                                          5.00        5.00
# mean                                           1.00        1.00
# std                                            0.00        0.00
# min                                            1.00        1.00
# 25%                                            1.00        1.00
# 50%                                            1.00        1.00
# 75%                                            1.00        1.00
# max                                            1.00        1.00
#
# SEG_DESC_ATTRIBUTE  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS  \
# count                                                           5.00
# mean                                                            1.00
# std                                                             0.00
# min                                                             1.00
# 25%                                                             1.00
# 50%                                                             1.00
# 75%                                                             1.00
# max                                                             1.00
#
# SEG_DESC_ATTRIBUTE  MINERAALWATER - PET SINGLESERVE  ORANGE  \
# count                                          5.00    5.00
# mean                                           1.00    1.00
# std                                            0.00    0.00
# min                                            1.00    1.00
# 25%                                            1.00    1.00
# 50%                                            1.00    1.00
# 75%                                            1.00    1.00
# max                                            1.00    1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - AO BRANDS  \
# count                                          5.00
# mean                                           1.00
# std                                            0.00
# min                                            1.00
# 25%                                            1.00
# 50%                                            1.00
# 75%                                            1.00
# max                                            1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - CRYSTAL CL  \
# count                                           5.00
# mean                                            1.00
# std                                             0.00
# min                                             1.00
# 25%                                             1.00
# 50%                                             1.00
# 75%                                             1.00
# max                                             1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - EIGEN MERK  \
# count                                           5.00
# mean                                            1.00
# std                                             0.00
# min                                             1.00
# 25%                                             1.00
# 50%                                             1.00
# 75%                                             1.00
# max                                             1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - SPA  \
# count                                    5.00
# mean                                     1.00
# std                                      0.00
# min                                      1.00
# 25%                                      1.00
# 50%                                      1.00
# 75%                                      1.00
# max                                      1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - AO BRANDS  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - FERNANDES  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - RIVELLA  OV.VRUCHT.LIM. - LIGHT  \
# count                                          5.00                    5.00
# mean                                           1.00                    1.00
# std                                            0.00                    0.00
# min                                            1.00                    1.00
# 25%                                            1.00                    1.00
# 50%                                            1.00                    1.00
# 75%                                            1.00                    1.00
# max                                            1.00                    1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                               5.00
# mean                                                1.00
# std                                                 0.00
# min                                                 1.00
# 25%                                                 1.00
# 50%                                                 1.00
# 75%                                                 1.00
# max                                                 1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - EIGEN MERK  \
# count                                                5.00
# mean                                                 1.00
# std                                                  0.00
# min                                                  1.00
# 25%                                                  1.00
# 50%                                                  1.00
# 75%                                                  1.00
# max                                                  1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - HERO  \
# count                                          5.00
# mean                                           1.00
# std                                            0.00
# min                                            1.00
# 25%                                            1.00
# 50%                                            1.00
# 75%                                            1.00
# max                                            1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - SPA  SPORT  TONIC  \
# count                                         5.00   5.00   5.00
# mean                                          1.00   1.00   1.00
# std                                           0.00   0.00   0.00
# min                                           1.00   1.00   1.00
# 25%                                           1.00   1.00   1.00
# 50%                                           1.00   1.00   1.00
# 75%                                           1.00   1.00   1.00
# max                                           1.00   1.00   1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - LIGHT  VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                              5.00                               5.00
# mean                               0.99                               1.00
# std                                0.03                               0.00
# min                                0.93                               1.00
# 25%                                1.00                               1.00
# 50%                                1.00                               1.00
# 75%                                1.00                               1.00
# max                                1.00                               1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                               5.00
# mean                                                1.00
# std                                                 0.00
# min                                                 1.00
# 25%                                                 1.00
# 50%                                                 1.00
# 75%                                                 1.00
# max                                                 1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHTENDRANK - AO BRANDS  VRUCHTENDRANK - APPELSIENTJE  \
# count                                    5.00                          5.00
# mean                                     1.00                          1.00
# std                                      0.00                          0.00
# min                                      1.00                          1.00
# 25%                                      1.00                          1.00
# 50%                                      1.00                          1.00
# 75%                                      1.00                          1.00
# max                                      1.00                          1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHTENDRANK - EIGEN MERK
# count                                     5.00
# mean                                      1.00
# std                                       0.00
# min                                       1.00
# 25%                                       1.00
# 50%                                       1.00
# 75%                                       1.00
# max                                       1.00

# %%
# Run as is
prev_row_cnt = forecastdf.shape[0]

tt = forecastdf[['Retailer','ds',FOCUS_ATTRIBUTE_COLUMN]].groupby(['Retailer',FOCUS_ATTRIBUTE_COLUMN]).count().reset_index()
tt.loc[:,'share_of_total_ds_with_data'] = tt.loc[:,'ds']/num_unique_timeperiods
drop_threshold = 0.5 # This is equivalent to 1yr if input is 2yrs worth of data. If only 1yr of data then set to 1
rows_to_keep = (tt.loc[tt['share_of_total_ds_with_data'] >= drop_threshold, 'Retailer'].str.cat(tt.loc[tt['share_of_total_ds_with_data'] >= drop_threshold, FOCUS_ATTRIBUTE_COLUMN])).tolist() # Drop rows will be those with < 1 yr of data to forecast with + nas
forecastdf = forecastdf.loc[forecastdf['Retailer'].str.cat(forecastdf[FOCUS_ATTRIBUTE_COLUMN]).isin(rows_to_keep)]

current_row_cnt = forecastdf.shape[0]

print(f'Dropped {current_row_cnt - prev_row_cnt} rows whose markets/attributes had insufficient data for forecasting. \nFinal dataset has {current_row_cnt} rows')
# Out:
# Dropped 0 rows whose markets/attributes had insufficient data for forecasting.
# Final dataset has 22568 rows

# %%
# Run as is
# Determine attributes to merge
"""
# Grouping Approach A -  Count of time period approach
# Calculate the % of Markets where the attribute is NaN i.e. Doesn't exist
count_sparsity = pd.DataFrame(attr_sparsity_report.count()/attr_sparsity_report.count().max())
mean_timeperiods_sparsity = pd.DataFrame(attr_sparsity_report.mean())
merge_threshold = 0.5 #40%

# Merge any attributes that are missing data in less than merge_threshold market/time_periods
attributes_to_group = count_sparsity.loc[count_sparsity[0] < merge_threshold].merge(
    mean_timeperiods_sparsity.loc[mean_timeperiods_sparsity[0] < merge_threshold], 
    on=FOCUS_ATTRIBUTE_COLUMN, how='outer').index.to_list()
"""
# Grouping Approach B -  Share of y
sparsity_y_based = forecastdf[[FOCUS_ATTRIBUTE_COLUMN,'y']].groupby([FOCUS_ATTRIBUTE_COLUMN]).agg(y_sum=("y","sum")).reset_index()
sparsity_y_based['y_share'] = sparsity_y_based['y_sum']/sparsity_y_based['y_sum'].sum()*100

try:
    attributes_to_group = sparsity_y_based.loc[sparsity_y_based['y_share'] < 0.05, FOCUS_ATTRIBUTE_COLUMN].unique().to_list()
    print(f"Merging the attributes below into an ALL OTHER group due to their low support: \n\n {attributes_to_group}")
except AttributeError: #empty list returned
    attributes_to_group = []
    print("There were no attributes to merge")
# Out:
# There were no attributes to merge

# %%
# Run as is
# Groups attributes if they have been flagged for merging
grouped_attributes_forecastdf = forecastdf.loc[forecastdf[FOCUS_ATTRIBUTE_COLUMN].isin(attributes_to_group)].groupby(['Retailer','ds']).sum().dropna(how='all').reset_index()
grouped_attributes_forecastdf[FOCUS_ATTRIBUTE_COLUMN] = 'ALL_OTHER_'+FOCUS_ATTRIBUTE_COLUMN

# Drop all rows which have been grouped then concatenate with the new grouped rows
forecastdf = pd.concat([forecastdf.loc[~forecastdf[FOCUS_ATTRIBUTE_COLUMN].isin(attributes_to_group)].reset_index(drop=True), grouped_attributes_forecastdf], 
          axis=0, ignore_index=True, sort=False).sort_values(by=['Retailer',FOCUS_ATTRIBUTE_COLUMN,'ds']).reset_index(drop=True)

# Summary of the data rows by market & unique time
attr_sparsity_report = forecastdf[['Retailer','ds',FOCUS_ATTRIBUTE_COLUMN]].groupby(['Retailer',FOCUS_ATTRIBUTE_COLUMN]).count().reset_index().pivot(
    index='Retailer', columns=FOCUS_ATTRIBUTE_COLUMN, values='ds')

num_unique_timeperiods = forecastdf['ds'].nunique()
for col in attr_sparsity_report.columns:
    attr_sparsity_report[col] = attr_sparsity_report[col]/num_unique_timeperiods

#attr_sparsity_report.to_excel('./attr_sparsity_report_'+FOCUS_ATTRIBUTE_COLUMN+'.xlsx')
attr_sparsity_report.describe()
# Out:
# SEG_DESC_ATTRIBUTE  AO SEGMENTS  COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                      5.00                                  5.00
# mean                       1.00                                  1.00
# std                        0.00                                  0.00
# min                        1.00                                  1.00
# 25%                        1.00                                  1.00
# 50%                        1.00                                  1.00
# 75%                        1.00                                  1.00
# max                        1.00                                  1.00
#
# SEG_DESC_ATTRIBUTE  COLA - LIGHT - EIGEN MERK  COLA - LIGHT - PEPSI  \
# count                                    5.00                  5.00
# mean                                     1.00                  1.00
# std                                      0.00                  0.00
# min                                      1.00                  1.00
# 25%                                      1.00                  1.00
# 50%                                      1.00                  1.00
# 75%                                      1.00                  1.00
# max                                      1.00                  1.00
#
# SEG_DESC_ATTRIBUTE  COLA - REGULAR - COCA COLA  COLA - REGULAR - EIGEN MERK  \
# count                                     5.00                         5.00
# mean                                      1.00                         1.00
# std                                       0.00                         0.00
# min                                       1.00                         1.00
# 25%                                       1.00                         1.00
# 50%                                       1.00                         1.00
# 75%                                       1.00                         1.00
# max                                       1.00                         1.00
#
# SEG_DESC_ATTRIBUTE  COLA - REGULAR - PEPSI & AO BRANDS  \
# count                                             5.00
# mean                                              1.00
# std                                               0.00
# min                                               1.00
# 25%                                               1.00
# 50%                                               1.00
# 75%                                               1.00
# max                                               1.00
#
# SEG_DESC_ATTRIBUTE  COLA - ZERO - COCA COLA  ENERGY - AO BRANDS  \
# count                                  5.00                5.00
# mean                                   1.00                1.00
# std                                    0.00                0.00
# min                                    1.00                1.00
# 25%                                    1.00                1.00
# 50%                                    1.00                1.00
# 75%                                    1.00                1.00
# max                                    1.00                1.00
#
# SEG_DESC_ATTRIBUTE  ENERGY - RED BULL  ICE_TEA_BLACK - CAN  \
# count                            5.00                 5.00
# mean                             1.00                 1.00
# std                              0.00                 0.00
# min                              1.00                 1.00
# 25%                              1.00                 1.00
# 50%                              1.00                 1.00
# 75%                              1.00                 1.00
# max                              1.00                 1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_BLACK - CARTON  ICE_TEA_BLACK - PET MULTISERVE  \
# count                                 5.00                            5.00
# mean                                  1.00                            1.00
# std                                   0.00                            0.00
# min                                   1.00                            1.00
# 25%                                   1.00                            1.00
# 50%                                   1.00                            1.00
# 75%                                   1.00                            1.00
# max                                   1.00                            1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_BLACK - PET SINGLESERVE  ICE_TEA_GREEN - CAN  \
# count                                          5.00                 5.00
# mean                                           1.00                 1.00
# std                                            0.00                 0.00
# min                                            1.00                 1.00
# 25%                                            1.00                 1.00
# 50%                                            1.00                 1.00
# 75%                                            1.00                 1.00
# max                                            1.00                 1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_GREEN - CARTON  ICE_TEA_GREEN - PET MULTISERVE  \
# count                                 5.00                            5.00
# mean                                  1.00                            1.00
# std                                   0.00                            0.00
# min                                   1.00                            1.00
# 25%                                   1.00                            1.00
# 50%                                   1.00                            1.00
# 75%                                   1.00                            1.00
# max                                   1.00                            1.00
#
# SEG_DESC_ATTRIBUTE  ICE_TEA_GREEN - PET SINGLESERVE  LEMON_LIME  \
# count                                          5.00        5.00
# mean                                           1.00        1.00
# std                                            0.00        0.00
# min                                            1.00        1.00
# 25%                                            1.00        1.00
# 50%                                            1.00        1.00
# 75%                                            1.00        1.00
# max                                            1.00        1.00
#
# SEG_DESC_ATTRIBUTE  MINERAALWATER - PET MULTISERVE & AO PACK FORMATS  \
# count                                                           5.00
# mean                                                            1.00
# std                                                             0.00
# min                                                             1.00
# 25%                                                             1.00
# 50%                                                             1.00
# 75%                                                             1.00
# max                                                             1.00
#
# SEG_DESC_ATTRIBUTE  MINERAALWATER - PET SINGLESERVE  ORANGE  \
# count                                          5.00    5.00
# mean                                           1.00    1.00
# std                                            0.00    0.00
# min                                            1.00    1.00
# 25%                                            1.00    1.00
# 50%                                            1.00    1.00
# 75%                                            1.00    1.00
# max                                            1.00    1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - AO BRANDS  \
# count                                          5.00
# mean                                           1.00
# std                                            0.00
# min                                            1.00
# 25%                                            1.00
# 50%                                            1.00
# 75%                                            1.00
# max                                            1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - CRYSTAL CL  \
# count                                           5.00
# mean                                            1.00
# std                                             0.00
# min                                             1.00
# 25%                                             1.00
# 50%                                             1.00
# 75%                                             1.00
# max                                             1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - EIGEN MERK  \
# count                                           5.00
# mean                                            1.00
# std                                             0.00
# min                                             1.00
# 25%                                             1.00
# 50%                                             1.00
# 75%                                             1.00
# max                                             1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - LIGHT - SPA  \
# count                                    5.00
# mean                                     1.00
# std                                      0.00
# min                                      1.00
# 25%                                      1.00
# 50%                                      1.00
# 75%                                      1.00
# max                                      1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - AO BRANDS  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - FERNANDES  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  OV.GAZEUSES - REGULAR - RIVELLA  OV.VRUCHT.LIM. - LIGHT  \
# count                                          5.00                    5.00
# mean                                           1.00                    1.00
# std                                            0.00                    0.00
# min                                            1.00                    1.00
# 25%                                            1.00                    1.00
# 50%                                            1.00                    1.00
# 75%                                            1.00                    1.00
# max                                            1.00                    1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                               5.00
# mean                                                1.00
# std                                                 0.00
# min                                                 1.00
# 25%                                                 1.00
# 50%                                                 1.00
# 75%                                                 1.00
# max                                                 1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - EIGEN MERK  \
# count                                                5.00
# mean                                                 1.00
# std                                                  0.00
# min                                                  1.00
# 25%                                                  1.00
# 50%                                                  1.00
# 75%                                                  1.00
# max                                                  1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - HERO  \
# count                                          5.00
# mean                                           1.00
# std                                            0.00
# min                                            1.00
# 25%                                            1.00
# 50%                                            1.00
# 75%                                            1.00
# max                                            1.00
#
# SEG_DESC_ATTRIBUTE  OV.VRUCHT.LIM. - REGULAR - SPA  SPORT  TONIC  \
# count                                         5.00   5.00   5.00
# mean                                          1.00   1.00   1.00
# std                                           0.00   0.00   0.00
# min                                           1.00   1.00   1.00
# 25%                                           1.00   1.00   1.00
# 50%                                           1.00   1.00   1.00
# 75%                                           1.00   1.00   1.00
# max                                           1.00   1.00   1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - LIGHT  VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                              5.00                               5.00
# mean                               0.99                               1.00
# std                                0.03                               0.00
# min                                0.93                               1.00
# 25%                                1.00                               1.00
# 50%                                1.00                               1.00
# 75%                                1.00                               1.00
# max                                1.00                               1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                               5.00
# mean                                                1.00
# std                                                 0.00
# min                                                 1.00
# 25%                                                 1.00
# 50%                                                 1.00
# 75%                                                 1.00
# max                                                 1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                            5.00
# mean                                             1.00
# std                                              0.00
# min                                              1.00
# 25%                                              1.00
# 50%                                              1.00
# 75%                                              1.00
# max                                              1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHTENDRANK - AO BRANDS  VRUCHTENDRANK - APPELSIENTJE  \
# count                                    5.00                          5.00
# mean                                     1.00                          1.00
# std                                      0.00                          0.00
# min                                      1.00                          1.00
# 25%                                      1.00                          1.00
# 50%                                      1.00                          1.00
# 75%                                      1.00                          1.00
# max                                      1.00                          1.00
#
# SEG_DESC_ATTRIBUTE  VRUCHTENDRANK - EIGEN MERK
# count                                     5.00
# mean                                      1.00
# std                                       0.00
# min                                       1.00
# 25%                                       1.00
# 50%                                       1.00
# 75%                                       1.00
# max                                       1.00

# %%
forecastdf = forecastdf.loc[forecastdf['y']>0]

# %% [markdown]
# This creates the forecasts by attribute value & market that we will use to factor out other external changes
#
# This code takes a while depending on the factors above. Typical is 3-5 mins if you have a "reasonable" # of unique values ~ < 30
#
# May take upwards of 30 mins for high cardinality attributes. I recommend clustering these before importing

# %%
@dask.delayed
def generate_prediction_delayed(dfpredict, myhols):
    #mdl = Prophet(seasonality_mode='multiplicative', seasonality_prior_scale=0.5)    
    ## add cap & floor for df & future
    mydf = dfpredict.copy()
    # Box-Cox transformation of Order 0
    mydf['y'] = np.log(1+mydf['y']) #log transform
    mydf['cap'] = mydf['y'].max()
    mydf['floor'] = 1
    
    mdl = Prophet(growth='logistic', changepoint_prior_scale=0.001, holidays=myhols, yearly_seasonality=True).fit(mydf, iter=100)
    
    # Create future dataset & forecast against
    future = mdl.make_future_dataframe(periods=52, freq='W')
    future['cap'] = mydf['y'].max()
    future['floor'] = 1
    #Maybe update hols here?

    # Predict
    forecast = mdl.predict(future)
    
    # Inverse Box-Cox
    forecast['yhat'] = np.exp(forecast['yhat']) - 1
    forecast['trend'] = np.exp(forecast['trend']) - 1

    # print("Calculating MAPE . . .")
    # df_mape = mapefn(dfpredict['y'], forecast['yhat'])

    # return mdl, df_mape
    return dask.delayed(forecast) # return delayed object since the function is expected to return a delayed

# %%
# Run as is
# Create dict of dfs which will each be individually forecasted by market & attribute
dictdfs = {k: v for k, v in forecastdf.groupby([FOCUS_ATTRIBUTE_COLUMN,'Retailer'])}
times_list = pd.to_datetime(forecastdf['ds'].to_list())
myhols = makeprophethols(times_list, future_periods=52, date_freq='W')
predictiondict = defaultdict(Prophet)
forecastdict = defaultdict(pd.DataFrame)

# %%
# Run as is

forecast_holder = []


for df_key, dfpredict in dictdfs.items():
    dfpredict_delayed = dask.delayed(dfpredict)
    forecast_holder.append(generate_prediction_delayed(dfpredict_delayed, myhols))
    #forecast_holder['MARKET'] = df_key
    #print(f"Type: {type(forecastdict[df_key])}")

#forecast_holder.append(forecastdf.groupby([FOCUS_ATTRIBUTE_COLUMN,'MARKET']).apply(generate_prediction_delayed(dfpredict_delayed, myhols)))
# This works but I don't understand why I have to compute twice (here and cell below) given how costly the function is
forecasts = dask.delayed(forecast_holder).compute()
forecasts
# Out:
# [Delayed('DataFrame-5872c183-41b6-489f-bf85-d5f1ba479725'),
#  Delayed('DataFrame-db16a3c9-eb70-410d-a00c-22200c671f79'),
#  Delayed('DataFrame-419aa3c1-d78d-4869-ad41-fc1ab89f783a'),
#  Delayed('DataFrame-acedddfa-21da-4e7a-9fdd-ed5b431d3fc6'),
#  Delayed('DataFrame-829051d6-113f-4fb9-b81a-4648a3123062'),
#  Delayed('DataFrame-c34279e3-ec2e-46f2-a914-d4ddf7a6c778'),
#  Delayed('DataFrame-af753ebd-512e-4941-929b-da9796e4e3af'),
#  Delayed('DataFrame-f940fe0e-e4a3-46b2-855a-906658fd7f61'),
#  Delayed('DataFrame-3c5c1817-4f90-45cf-b385-6ec807e78762'),
#  Delayed('DataFrame-b12a43d7-0510-4b72-93e7-ff2969e9cf14'),
#  Delayed('DataFrame-d6d44774-15a0-41f7-b100-9784dcd4feb4'),
#  Delayed('DataFrame-a62fa4ce-b06a-4fc9-8b7d-dc3bdd5131dc'),
#  Delayed('DataFrame-69a8bcde-02c1-430e-a729-cd2cf5208688'),
#  Delayed('DataFrame-f26e0903-9d09-4268-836c-12256727688f'),
#  Delayed('DataFrame-c2f6747a-e1f9-4cd4-9694-edd2662e94a6'),
#  Delayed('DataFrame-91d1535c-7079-4335-bc3a-317db1fc9fb6'),
#  Delayed('DataFrame-c9ba2a15-235f-4f1f-a8b7-2ff43a2d9c43'),
#  Delayed('DataFrame-a4952802-b01e-4abf-8b77-fae6ac389bec'),
#  Delayed('DataFrame-e349a010-df13-4d1a-8b0f-f4bb9ce9805d'),
#  Delayed('DataFrame-745f4ba1-c45d-43b3-a86d-44ce873159e9'),
#  Delayed('DataFrame-dd7a01b3-c19d-4a2a-a8d7-3b14d12a476a'),
#  Delayed('DataFrame-be73d55d-3eae-4b13-b50b-8b4d0bd5db64'),
#  Delayed('DataFrame-e88d20a0-389b-4515-b705-e7df67e60565'),
#  Delayed('DataFrame-2f896c49-ea98-4f3c-8a13-efbb69f3d025'),
#  Delayed('DataFrame-0f9cdd3c-bb89-4c7b-9391-10cfdb6df90f'),
#  Delayed('DataFrame-3e88dba2-4491-4456-8c56-b1f0c5257cbc'),
#  Delayed('DataFrame-b5f15c18-b8ab-47fb-82fa-6dab0c417221'),
#  Delayed('DataFrame-a66a7509-34ca-4130-be9d-27db7dfa6cf3'),
#  Delayed('DataFrame-93bb9c90-8e90-4567-85c9-d4769bf0b819'),
#  Delayed('DataFrame-11a9d71f-5566-4d89-a7bb-2237d4abd2de'),
#  Delayed('DataFrame-a8c32612-9ae1-49a6-b6a6-23f22c69b9c0'),
#  Delayed('DataFrame-e4f72ce9-e9ea-411d-a2b2-9f8c98e5c062'),
#  Delayed('DataFrame-2900839c-fbf1-4149-b43a-969ae25857a9'),
#  Delayed('DataFrame-afd9b37b-fb1b-48eb-832f-d427272763f4'),
#  Delayed('DataFrame-0c468b64-0211-4699-88d1-80762dfddd07'),
#  Delayed('DataFrame-bc1027c8-268f-456e-a923-0997ac373360'),
#  Delayed('DataFrame-eed28c83-0332-408f-a31d-aa9db11f3ecd'),
#  Delayed('DataFrame-2d7c0d4b-5b89-4095-854b-37f9c14fb36a'),
#  Delayed('DataFrame-f5ba08b7-f5fd-4489-91c4-c497c9ac01b3'),
#  Delayed('DataFrame-a7d1434a-b2fe-4af4-9ef0-5dea9a5f04f6'),
#  Delayed('DataFrame-44ceba44-584c-464d-a910-65aa83df63fc'),
#  Delayed('DataFrame-b00832d2-3048-45d0-9985-8c907f774a3c'),
#  Delayed('DataFrame-84059ea1-df29-45ab-a385-f31e4fc78eac'),
#  Delayed('DataFrame-1ef56629-2860-443b-bf32-c7dabe1f79d1'),
#  Delayed('DataFrame-4d573ba5-dc4b-43e4-91f2-0c98fcb9c7ff'),
#  Delayed('DataFrame-f8160397-ce17-4528-b5a0-37ab881677b8'),
#  Delayed('DataFrame-f22e4e08-d3b7-494f-8875-bf4e2277fdf5'),
#  Delayed('DataFrame-a05ad870-9914-4d97-8de8-9f908d3eff58'),
#  Delayed('DataFrame-6b035f3b-c9fc-4ebf-9d23-6ec4e9aa23cd'),
#  Delayed('DataFrame-d5c001a5-34a6-45bb-bd6a-6b05b9e47861'),
#  Delayed('DataFrame-6091fa68-e022-4fc6-8617-4568ce523206'),
#  Delayed('DataFrame-15251d17-b7ee-4b0a-9624-cefbf538bfb4'),
#  Delayed('DataFrame-e0d680f2-710d-4160-8bfe-f293d3f26c30'),
#  Delayed('DataFrame-c3c5f45c-2892-4006-a77e-dc373b8e0ad6'),
#  Delayed('DataFrame-d8de690f-3bbe-497e-b689-52316e0ddc5c'),
#  Delayed('DataFrame-43a0c134-dc0e-4849-9074-022fdd4bacab'),
#  Delayed('DataFrame-91a2fa56-6964-4823-991f-bd464f8d3d9f'),
#  Delayed('DataFrame-cdf3b65d-0cf9-4a7a-8075-c2f3e354cce7'),
#  Delayed('DataFrame-2521fbab-7a5e-4b9b-8eeb-35211c273a2a'),
#  Delayed('DataFrame-ea2f2a59-7356-4ef4-bf79-e6115e22c4ed'),
#  Delayed('DataFrame-fc54a4d0-32f2-41a2-befc-09b748cea4cc'),
#  Delayed('DataFrame-037d241f-3bb8-41f9-9c65-4e35b941f8e0'),
#  Delayed('DataFrame-cd2358d6-5c20-4b1c-8aa3-a6833378a22c'),
#  Delayed('DataFrame-071b0fe4-ff29-48b9-8a97-64ef2b2d71b2'),
#  Delayed('DataFrame-a4320b5a-e600-4627-9da6-dc8f726de78f'),
#  Delayed('DataFrame-823d0f57-fa37-4f2e-aac9-1ea64798c1d7'),
#  Delayed('DataFrame-22106576-e7a3-4ca1-a230-3e8dfce66d4d'),
#  Delayed('DataFrame-70d08f5e-9cd3-4c47-9457-62e5f69bcad9'),
#  Delayed('DataFrame-279ebb41-fee9-41ef-8f00-9d29e5e73780'),
#  Delayed('DataFrame-7a39fbee-5a2c-4496-959e-f7fa55c4d219'),
#  Delayed('DataFrame-98ae8c9c-42d5-42c3-a71f-30f7cb11914a'),
#  Delayed('DataFrame-726fa476-8f11-4f54-a161-0ee1db2e98ce'),
#  Delayed('DataFrame-799758eb-31f8-4997-871d-84e548065d5b'),
#  Delayed('DataFrame-aacede22-cd98-4ddc-8869-ddd332965a70'),
#  Delayed('DataFrame-c59bd03e-35bf-44eb-9fb5-1240a0153e82'),
#  Delayed('DataFrame-1c632b09-0a11-4532-86fe-3e811b665fd0'),
#  Delayed('DataFrame-66df8d6d-9b4a-4f72-8bff-d59add0a8af1'),
#  Delayed('DataFrame-abf54d91-9c1e-4806-8cea-c3f88ccd57fe'),
#  Delayed('DataFrame-87f6fc64-f36e-4f05-9c6b-8bbe51faefca'),
#  Delayed('DataFrame-66a131a6-3391-4611-a204-c9b24a2c52df'),
#  Delayed('DataFrame-cbca1dc5-c475-4364-8bbc-676e4097109f'),
#  Delayed('DataFrame-927b8797-5ace-4e47-8cd8-5a82d2683bff'),
#  Delayed('DataFrame-fed53009-18ca-4cf9-9697-becba6a1f6b8'),
#  Delayed('DataFrame-dbacc4dc-eacf-471c-879f-ea2b7206e679'),
#  Delayed('DataFrame-0bf61087-7c6b-4961-b2b7-5f1fa3112248'),
#  Delayed('DataFrame-f2cc6004-f8c8-47ed-afc6-5a2dd12895cb'),
#  Delayed('DataFrame-4f8238e7-0b3c-4e42-bd8c-36f238e32383'),
#  Delayed('DataFrame-30222012-5d93-4c6b-a95c-ff274846b8d0'),
#  Delayed('DataFrame-f9a4d9eb-5137-42ca-b474-612d35b810cc'),
#  Delayed('DataFrame-188158a2-58a4-49a7-a716-efe31b75eece'),
#  Delayed('DataFrame-a8fe5b4e-e654-4dec-a251-d6d3f237b1b5'),
#  Delayed('DataFrame-e78fc460-fc38-4cbd-bd3a-3e26c2bf2b95'),
#  Delayed('DataFrame-4660ef51-d097-4a39-87b9-6c9ac17c2c6b'),
#  Delayed('DataFrame-676632be-57ed-41ef-b827-65cac690ff7d'),
#  Delayed('DataFrame-687c40cb-6734-4e92-a40e-ff3ace363aab'),
#  Delayed('DataFrame-2a02bee2-f78a-4432-986a-7e3f92ac69e2'),
#  Delayed('DataFrame-263b0409-2d3b-4546-8015-8a79619ee53c'),
#  Delayed('DataFrame-fd8273ce-eacc-4aba-8e36-72661572ce57'),
#  Delayed('DataFrame-829b81fc-345f-4fe3-b08d-d48a62119258'),
#  Delayed('DataFrame-023c5ff6-d91f-4e4a-bcf5-0844a5895e79'),
#  Delayed('DataFrame-629e1208-5132-4fac-ad6b-3face98b3f9f'),
#  Delayed('DataFrame-fc2ed88b-dfc4-4243-bba3-fe046a37837f'),
#  Delayed('DataFrame-b945a739-c133-4e45-982b-86ff4af704e7'),
#  Delayed('DataFrame-956b50a8-9989-4b60-87c6-8c3bfa60c96d'),
#  Delayed('DataFrame-c299f03a-ac43-4b0e-9c21-4c956dabae2a'),
#  Delayed('DataFrame-637c3722-5cf1-4e0f-94e4-bfb1b0a7ebf6'),
#  Delayed('DataFrame-143f1deb-a5c0-4679-99ee-c5ba9c3cabfe'),
#  Delayed('DataFrame-e79b5d32-e416-41b3-b3ad-a7816acc0f3d'),
#  Delayed('DataFrame-597355c5-d903-403b-b752-447232bd2a28'),
#  Delayed('DataFrame-fae56eca-8fdb-4df8-80e6-26a7c3ea2a9d'),
#  Delayed('DataFrame-a3b87d1d-07ce-4ed4-82f4-0e76da81a5dc'),
#  Delayed('DataFrame-bd58dcad-ce4a-4814-9494-0d57d8be953d'),
#  Delayed('DataFrame-0ab4832b-b28e-4e26-815e-eba255850f27'),
#  Delayed('DataFrame-8f766d9e-1494-4d2a-8fdf-0966c78479da'),
#  Delayed('DataFrame-ee2272c8-ed9d-44e4-885d-a4e6dc22c12a'),
#  Delayed('DataFrame-061eb310-1ab0-4a7f-a392-c7d64160b461'),
#  Delayed('DataFrame-c52f6bd0-68ee-473b-9166-d848c6a0a970'),
#  Delayed('DataFrame-ea6d9142-8956-48f5-bf7c-930d05e8ae80'),
#  Delayed('DataFrame-2bb2df0e-1103-41ce-bcf3-ce7b14cc06fa'),
#  Delayed('DataFrame-b04123c4-2020-4929-b14a-51a1dc75b76f'),
#  Delayed('DataFrame-482dd0bf-f4c5-4ccf-a4b2-11578bfa9022'),
#  Delayed('DataFrame-b4d0145e-b943-49ad-96f0-7e7c97435242'),
#  Delayed('DataFrame-c5c8c29c-ce48-4826-be2d-f92c6132b0da'),
#  Delayed('DataFrame-9937b5f7-1255-4bfe-84c5-d4849b23082d'),
#  Delayed('DataFrame-6806c357-c7a8-4889-ac04-3c589a994cc2'),
#  Delayed('DataFrame-25d8aecc-aa64-4bdb-9eb1-ba369443fd1c'),
#  Delayed('DataFrame-11ac1342-3aae-421a-8e5e-b0d0adc07f21'),
#  Delayed('DataFrame-cf3b5c8d-160d-46ac-9d92-9a35dd23ea46'),
#  Delayed('DataFrame-dab6f2c9-48d8-4fc8-b692-071774a28705'),
#  Delayed('DataFrame-092a09f4-c3c3-4c90-a504-47c3c6095df8'),
#  Delayed('DataFrame-10229ac9-ba39-49eb-82c3-64a3e421df45'),
#  Delayed('DataFrame-5e12d825-34cd-44ef-9d84-27a9dbc40504'),
#  Delayed('DataFrame-c40ea2d5-99b5-4026-af76-5e68bc91e9a2'),
#  Delayed('DataFrame-a89f67ac-9d66-4540-a47d-1870d0b1b719'),
#  Delayed('DataFrame-12dc500a-45ef-49c7-8f4e-ab99d7db2ba9'),
#  Delayed('DataFrame-2f6bcecf-bc54-4e35-bd65-aa0d149d3ad2'),
#  Delayed('DataFrame-309974b3-cc18-4e49-8c84-a0d2d6e92619'),
#  Delayed('DataFrame-90d2c407-7dbc-4de8-bf37-830c3b95f576'),
#  Delayed('DataFrame-e1f6a1ea-dcca-437c-be07-b7370f679d92'),
#  Delayed('DataFrame-fbb174e9-d95c-4808-bb4f-3738696f5d3e'),
#  Delayed('DataFrame-05bc1692-d350-4b60-8031-419ffa316d73'),
#  Delayed('DataFrame-de16ae63-7b3f-4268-a681-c6a6b808df5c'),
#  Delayed('DataFrame-4ef95e00-a962-4f9c-a64c-278841e1ec57'),
#  Delayed('DataFrame-6f0b4481-2057-4e0b-b84a-b63d74753c47'),
#  Delayed('DataFrame-1d2a7fee-ef55-414f-b995-62f82644572e'),
#  Delayed('DataFrame-13627bf9-87f4-417e-a7ac-441c34a92ee3'),
#  Delayed('DataFrame-f56822c1-5c7b-423d-a51d-aba880301f38'),
#  Delayed('DataFrame-a6c45a4f-fd74-41a8-a0d8-71d352da6d13'),
#  Delayed('DataFrame-7dd953cc-c285-4112-a8b9-585158d9989f'),
#  Delayed('DataFrame-48677770-5ad2-4fc3-9f7e-36fcd48ca2f8'),
#  Delayed('DataFrame-ad8b3f03-886c-4751-b984-6bcf6564c36d'),
#  Delayed('DataFrame-fb61616e-4067-4775-a50c-ba6880863e78'),
#  Delayed('DataFrame-68ea2b2d-08c3-40a2-9c57-bbf2e52b0082'),
#  Delayed('DataFrame-00598b4b-9153-4669-b852-1408052f0f63'),
#  Delayed('DataFrame-a30d7bb7-394e-4274-bd3a-1b6ec9c80f2d'),
#  Delayed('DataFrame-d63e0a60-10d1-4077-aa70-88467ea62415'),
#  Delayed('DataFrame-6cd1dfe9-2f51-4bec-8255-826cd723a88c'),
#  Delayed('DataFrame-4aa365b8-3212-4b00-a829-9922e0874d2c'),
#  Delayed('DataFrame-9cf2822e-89cd-42aa-88a4-ce69da20995f'),
#  Delayed('DataFrame-83d32516-5399-4627-9fe7-b44dce43f91f'),
#  Delayed('DataFrame-338fc2cb-6106-4d04-bae6-229b0a962f04'),
#  Delayed('DataFrame-7eacf479-7bb2-45c0-abf0-22c484e56499'),
#  Delayed('DataFrame-2589514f-38d7-45b8-b691-26d82dca85ac'),
#  Delayed('DataFrame-efc7e8f5-1047-4dd7-99e2-f3ec7c8d694f'),
#  Delayed('DataFrame-8a053bc1-15e3-4787-adac-6ddb9ff3f1f0'),
#  Delayed('DataFrame-22227f9f-a726-4ef9-b14d-cac0f17f1c16'),
#  Delayed('DataFrame-ead6f2ce-7c05-4c01-81fd-d56bdbfe569e'),
#  Delayed('DataFrame-ea9aab9c-04a6-416b-bc38-3ef88662a05a'),
#  Delayed('DataFrame-8ea44a03-79a9-4179-82c3-42945494d52f'),
#  Delayed('DataFrame-eba76310-30e7-4a04-a97e-5875379a28e2'),
#  Delayed('DataFrame-55389472-b04d-4891-a14a-062b255a86d0'),
#  Delayed('DataFrame-b7c750b5-e2ad-46a6-88ae-c1e6f71a96db'),
#  Delayed('DataFrame-f3c2465a-eba3-41fe-8235-99ee1e64142e'),
#  Delayed('DataFrame-9797c993-a92b-4cb7-9fd2-eae9c36b8fd3'),
#  Delayed('DataFrame-773c1587-ecac-4941-ba2a-35d903b922be'),
#  Delayed('DataFrame-547ac9c3-1640-4c20-9d62-799ac270715d'),
#  Delayed('DataFrame-304651bb-c3f7-428a-b6fc-bb9b0923d751'),
#  Delayed('DataFrame-986afe67-2eb8-40d2-a7b0-127c4e7019a5'),
#  Delayed('DataFrame-76061777-b985-4eb3-97cc-d5e98e0d96da'),
#  Delayed('DataFrame-dfa07524-848f-47e8-b9af-9a59b46cfc29'),
#  Delayed('DataFrame-8e4b0fcc-a3be-414c-a6d5-e3c0fc8b02a7'),
#  Delayed('DataFrame-78b4be01-4e11-4d1b-9229-7125c88b4d33'),
#  Delayed('DataFrame-7baf8a0b-abde-464b-812c-2f051f7dd90c'),
#  Delayed('DataFrame-0a411251-76f4-45fa-ad48-8c8f13fe7014'),
#  Delayed('DataFrame-2a573c6b-7dc5-47e9-b031-ccd7bcce21aa'),
#  Delayed('DataFrame-2ab1b371-9c89-4ec7-8004-e879babb33d1'),
#  Delayed('DataFrame-9b3da65c-b136-4833-8bf6-16ccc9fb8321'),
#  Delayed('DataFrame-e2f3d4ec-2223-41b1-82d5-ed4e29d885b2'),
#  Delayed('DataFrame-6c45c3de-370f-4020-a0e0-540f95bd495e'),
#  Delayed('DataFrame-cbce714d-fbb5-4cba-a0c1-9ae8ac17eb40'),
#  Delayed('DataFrame-597bcde0-053b-4114-88d4-6338302688bc'),
#  Delayed('DataFrame-64ac966c-d57f-4593-9a5d-7ccd63f4be65'),
#  Delayed('DataFrame-b9de83c0-8e53-4b17-a643-9e48dbfd1f8b'),
#  Delayed('DataFrame-19a9107e-8c13-4819-ab2f-93c741a4b391'),
#  Delayed('DataFrame-30a83639-03cf-4ecd-afb1-3c6677da010b'),
#  Delayed('DataFrame-0c3555cd-4578-4368-928d-3462e63c51de'),
#  Delayed('DataFrame-422c0762-aa18-414b-91bd-12eb556ee097'),
#  Delayed('DataFrame-b671595f-f087-4470-8f41-5646d0c275b2'),
#  Delayed('DataFrame-b679443d-56e5-4779-971d-aed78105ce31'),
#  Delayed('DataFrame-02194085-b0ec-4100-9a16-31291ceae0a8'),
#  Delayed('DataFrame-661581f4-1d30-4559-ba74-9a3915665843'),
#  Delayed('DataFrame-66c823be-b23d-467b-9ef9-b993c5441bb0'),
#  Delayed('DataFrame-bc6c7d2e-b6b7-48b1-a94d-57201c7d5546'),
#  Delayed('DataFrame-1bcbba1c-8fa1-467f-a0e2-746147f7df4a'),
#  Delayed('DataFrame-8b3628c8-253a-432e-b125-bd43edb02a79'),
#  Delayed('DataFrame-c2684dac-c0d0-4db3-a0e3-d67ce7d1d04f'),
#  Delayed('DataFrame-0100c2e6-f6d5-4c3f-9dc5-917abb937745'),
#  Delayed('DataFrame-023d89fe-8e9c-42df-a7c8-81dad889348e'),
#  Delayed('DataFrame-c44cf233-e338-4dda-b998-b316feab2b49'),
#  Delayed('DataFrame-5f6e1c74-3d8d-4496-8a43-a50f5451c6df'),
#  Delayed('DataFrame-cc77945e-fdcf-43fe-a2ac-ce5c341b8ccf'),
#  Delayed('DataFrame-cab093e4-e562-4212-b60d-f7d4acd6ebdb'),
#  Delayed('DataFrame-cd25050f-c620-460d-8efd-12e27327e629'),
#  Delayed('DataFrame-930082be-9032-4002-9b23-1129d59dfaa5'),
#  Delayed('DataFrame-7bedff14-7408-48de-9078-2e6ec8ea0afd')]

# %%
# Run as is
# y = the metric of focus -> typically should be BASE_UNITS
# yhat = forecasted value for y in that attribute, period & market
# catsales_nonforecast = y - yhat

dfcatforecast = pd.DataFrame()
for i in range(len(dictdfs.keys())):
    tempdf = forecasts[i].compute()
    tempdf[FOCUS_ATTRIBUTE_COLUMN], tempdf['Retailer'] = list(dictdfs.keys())[i]
    dfcatforecast = dfcatforecast.append(tempdf)
    
forecastdf = forecastdf.merge(dfcatforecast[[FOCUS_ATTRIBUTE_COLUMN,'Retailer','ds','yhat','trend']], 
                              how='left', on=[FOCUS_ATTRIBUTE_COLUMN,'Retailer','ds'], suffixes=("","_y"))
#forecastdf['catsales_nonforecast'] = forecastdf['y'] - forecastdf['yhat']
forecastdf['catsales_nonforecast'] = forecastdf['y'] - forecastdf['trend']

forecastdf[['y','yhat','trend','catsales_nonforecast']].describe()
# Out:
#                  y       yhat      trend  catsales_nonforecast
# count    22,568.00  22,568.00  22,568.00             22,568.00
# mean     76,795.91  78,013.34  76,636.97                158.94
# std     126,295.02 118,217.66 114,630.49             48,437.22
# min           1.00       0.98      43.42           -391,615.84
# 25%       9,474.50  11,673.68  11,450.72             -8,518.03
# 50%      30,372.00  35,835.47  35,157.73             -1,060.26
# 75%      86,569.75  85,993.62  85,614.54              4,837.10
# max   1,174,931.00 912,534.13 761,543.10            549,550.43

# %%
# Run as is
forecastdf_filtered = forecastdf.copy()
forecastdf_filtered['catsales_nonforecast_perc'] = forecastdf_filtered['catsales_nonforecast']/forecastdf_filtered['y']
# If deviation is <1%, set to np.nan
forecastdf_filtered.loc[abs(forecastdf_filtered['catsales_nonforecast_perc']) < 0.01, 'catsales_nonforecast'] = np.nan 
forecastdf_filtered.drop('catsales_nonforecast_perc', axis=1, inplace=True)
# Check for % of sales that are not accounted for by forecasted trend & seasonality
pd.DataFrame(forecastdf_filtered['catsales_nonforecast']/forecastdf_filtered['y']).describe()
# Out:
#               0
# count 21,922.00
# mean      -0.42
# std        2.06
# min     -124.98
# 25%       -0.40
# 50%       -0.07
# 75%        0.14
# max        0.96

# %%
# Run as is
# Merge category forecast to original dataset & create regression base dataset
#forecastdf_new = createfile(forecastdf_filtered, valcol='catsales_nonforecast', tdpcol='ACV').dropna(how='all')
forecastdf_new = createfile(forecastdf_filtered, valcol='y', tdpcol='ACV').dropna(how='all')
# "Saves" value of focus attribute in a new column as this will be removed by get_dummies
forecastdf_new.loc[:,FOCUS_ATTRIBUTE_COLUMN+'2'] = forecastdf_new.loc[:,FOCUS_ATTRIBUTE_COLUMN].copy()

metriccols= forecastdf_new.columns[forecastdf_new.columns.str.contains('perc')].to_flat_index().to_list()
dummycols = list(FOCUS_ATTRIBUTE_COLUMN + "_"+ forecastdf_new[FOCUS_ATTRIBUTE_COLUMN].unique())
forecastdf_dummy = pd.get_dummies(forecastdf_new, columns=[FOCUS_ATTRIBUTE_COLUMN])
for col in dummycols:
    for col2 in metriccols:
        forecastdf_dummy[col2 +'_' +col] = forecastdf_dummy[col] * forecastdf_dummy[col2]
        
# Restores focus attribute column
forecastdf_dummy.rename(columns={FOCUS_ATTRIBUTE_COLUMN+'2':FOCUS_ATTRIBUTE_COLUMN}, inplace=True)

# Create regression aggregated dataset - By Market & Time Period
forecastdf_dummy.replace(0, np.nan, inplace=True) #Prevent zeros from messing the means
forecastdf_dummy_agg = forecastdf_dummy.loc[:,
                                            [FOCUS_ATTRIBUTE_COLUMN,'Retailer','ds'] + 
                                            forecastdf_dummy.columns[
                                                forecastdf_dummy.columns.str.contains('perc') & 
                                                # ensure line below has your attribute name
                                                forecastdf_dummy.columns.str.contains(FOCUS_ATTRIBUTE_COLUMN) &
                                                ~forecastdf_dummy.columns.str.contains('4wk')
                                            ].to_flat_index().to_list()].groupby(['Retailer','ds']).mean().reset_index()


forecastdf_dummy_agg.describe()
# Out:
# C:\Users\TRAINO~1\AppData\Local\Temp/ipykernel_22928/1646407835.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   forecastdf_dummy[col2 +'_' +col] = forecastdf_dummy[col] * forecastdf_dummy[col2]
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                        523.00
# mean                                           0.17
# std                                            0.81
# min                                           -0.94
# 25%                                           -0.14
# 50%                                            0.01
# 75%                                            0.24
# max                                           10.65
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                         524.00
# mean                                            0.00
# std                                             0.06
# min                                            -0.30
# 25%                                            -0.01
# 50%                                            -0.00
# 75%                                             0.00
# max                                             0.73
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                        522.00
# mean                                           0.06
# std                                            1.17
# min                                           -3.74
# 25%                                           -0.25
# 50%                                           -0.00
# 75%                                            0.23
# max                                           11.10
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                         522.00
# mean                                            0.00
# std                                             0.09
# min                                            -0.31
# 25%                                            -0.02
# 50%                                            -0.00
# 75%                                             0.01
# max                                             0.73
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             524.00
# mean                                                0.02
# std                                                 0.22
# min                                                -0.55
# 25%                                                -0.11
# 50%                                                -0.01
# 75%                                                 0.10
# max                                                 1.51
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.04
# min                                                -0.37
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.20
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             525.00
# mean                                               -0.01
# std                                                 0.26
# min                                                -1.48
# 25%                                                -0.12
# 50%                                                -0.00
# 75%                                                 0.10
# max                                                 1.23
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             525.00
# mean                                               -0.01
# std                                                 0.07
# min                                                -0.37
# 25%                                                -0.03
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 0.34
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             525.00
# mean                                                0.05
# std                                                 0.35
# min                                                -0.60
# 25%                                                -0.05
# 50%                                                 0.00
# 75%                                                 0.07
# max                                                 4.94
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             525.00
# mean                                                0.02
# std                                                 0.15
# min                                                -0.13
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 2.16
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             525.00
# mean                                                0.06
# std                                                 0.53
# min                                                -1.15
# 25%                                                -0.05
# 50%                                                 0.00
# 75%                                                 0.09
# max                                                 6.55
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             525.00
# mean                                                0.03
# std                                                 0.22
# min                                                -0.20
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 2.13
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             525.00
# mean                                                0.18
# std                                                 0.79
# min                                                -0.86
# 25%                                                -0.19
# 50%                                                 0.01
# 75%                                                 0.31
# max                                                 7.44
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.07
# min                                                -0.65
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.62
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             525.00
# mean                                                0.00
# std                                                 1.06
# min                                                -7.25
# 25%                                                -0.29
# 50%                                                -0.01
# 75%                                                 0.26
# max                                                 4.86
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             525.00
# mean                                                0.00
# std                                                 0.10
# min                                                -0.66
# 25%                                                -0.03
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 0.63
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             525.00
# mean                                                0.07
# std                                                 0.60
# min                                                -0.58
# 25%                                                -0.10
# 50%                                                -0.00
# 75%                                                 0.12
# max                                                 9.56
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             525.00
# mean                                                0.01
# std                                                 0.09
# min                                                -0.11
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 1.43
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             525.00
# mean                                                0.10
# std                                                 0.77
# min                                                -1.25
# 25%                                                -0.10
# 50%                                                -0.00
# 75%                                                 0.14
# max                                                 8.44
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             525.00
# mean                                                0.01
# std                                                 0.11
# min                                                -0.16
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 1.26
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             525.00
# mean                                                0.01
# std                                                 0.18
# min                                                -0.85
# 25%                                                -0.06
# 50%                                                 0.00
# 75%                                                 0.06
# max                                                 0.97
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.05
# min                                                -0.66
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.24
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             525.00
# mean                                               -0.01
# std                                                 0.24
# min                                                -1.66
# 25%                                                -0.06
# 50%                                                 0.00
# 75%                                                 0.07
# max                                                 0.88
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.08
# min                                                -0.66
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 0.43
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - PEPSI & AO BRANDS  \
# count                                             524.00
# mean                                                0.09
# std                                                 0.54
# min                                                -0.75
# 25%                                                -0.16
# 50%                                                 0.00
# 75%                                                 0.17
# max                                                 2.86
#
#        ...  dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - LIGHT  \
# count  ...                                             518.00
# mean   ...                                               0.10
# std    ...                                               1.14
# min    ...                                              -1.29
# 25%    ...                                              -0.02
# 50%    ...                                              -0.00
# 75%    ...                                               0.01
# max    ...                                              19.37
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             525.00
# mean                                                0.07
# std                                                 0.45
# min                                                -0.84
# 25%                                                -0.13
# 50%                                                 0.00
# 75%                                                 0.14
# max                                                 3.64
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             525.00
# mean                                                0.02
# std                                                 0.21
# min                                                -0.15
# 25%                                                -0.02
# 50%                                                -0.01
# 75%                                                 0.00
# max                                                 2.93
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             525.00
# mean                                                0.05
# std                                                 0.75
# min                                                -3.19
# 25%                                                -0.15
# 50%                                                 0.00
# 75%                                                 0.15
# max                                                 8.42
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             525.00
# mean                                                0.03
# std                                                 0.29
# min                                                -0.41
# 25%                                                -0.03
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 2.92
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             525.00
# mean                                                0.57
# std                                                 1.65
# min                                                -0.92
# 25%                                                -0.46
# 50%                                                 0.02
# 75%                                                 0.94
# max                                                 8.32
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             523.00
# mean                                               -0.00
# std                                                 0.09
# min                                                -0.55
# 25%                                                -0.02
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.56
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             525.00
# mean                                                0.09
# std                                                 2.51
# min                                                -8.46
# 25%                                                -0.65
# 50%                                                 0.00
# 75%                                                 0.69
# max                                                13.73
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             524.00
# mean                                               -0.01
# std                                                 0.13
# min                                                -0.55
# 25%                                                -0.04
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.56
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             524.00
# mean                                                0.23
# std                                                 1.38
# min                                                -0.90
# 25%                                                -0.08
# 50%                                                -0.01
# 75%                                                 0.09
# max                                                19.60
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             512.00
# mean                                                0.00
# std                                                 0.10
# min                                                -0.32
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 1.78
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             525.00
# mean                                                0.14
# std                                                 1.84
# min                                               -11.51
# 25%                                                -0.11
# 50%                                                -0.01
# 75%                                                 0.09
# max                                                13.75
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             516.00
# mean                                                0.00
# std                                                 0.12
# min                                                -0.44
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 1.61
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             525.00
# mean                                                0.22
# std                                                 0.90
# min                                                -0.85
# 25%                                                -0.09
# 50%                                                -0.00
# 75%                                                 0.13
# max                                                 6.42
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             525.00
# mean                                                0.01
# std                                                 0.17
# min                                                -0.21
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 3.53
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             525.00
# mean                                                0.03
# std                                                 1.29
# min                                                -6.32
# 25%                                                -0.13
# 50%                                                -0.00
# 75%                                                 0.17
# max                                                 5.27
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             525.00
# mean                                                0.02
# std                                                 0.23
# min                                                -0.21
# 25%                                                -0.02
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 3.53
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             525.00
# mean                                                0.37
# std                                                 1.18
# min                                                -0.89
# 25%                                                -0.20
# 50%                                                 0.01
# 75%                                                 0.51
# max                                                 5.73
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.04
# min                                                -0.29
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.45
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             525.00
# mean                                                0.08
# std                                                 1.88
# min                                                -5.70
# 25%                                                -0.42
# 50%                                                -0.00
# 75%                                                 0.33
# max                                                 9.46
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             525.00
# mean                                               -0.00
# std                                                 0.07
# min                                                -0.29
# 25%                                                -0.02
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 0.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             525.00
# mean                                                0.02
# std                                                 0.22
# min                                                -0.38
# 25%                                                -0.04
# 50%                                                 0.00
# 75%                                                 0.05
# max                                                 4.27
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.08
# min                                                -0.14
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.94
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             525.00
# mean                                                0.03
# std                                                 0.29
# min                                                -0.66
# 25%                                                -0.05
# 50%                                                 0.01
# 75%                                                 0.06
# max                                                 3.97
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK
# count                                             524.00
# mean                                                0.01
# std                                                 0.11
# min                                                -0.19
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.92
#
# [8 rows x 172 columns]

# %% [markdown]
# The next code cell filters down the regression dataset by filtering outliers.
#
# Change the 'perc_limit' variable below only if your 25%/75% percentile values are greater than 3 in absolute terms (Use the Guideline comment).
#
# Else run as-is
#
# Finally, compare the Count row to see how many rows have been filtered out and adjust accordingly

# %%
# Filter out extreme swings in non-forecasted sales i.e. greater than 300% change (likely due to some Promo effect)

# Select only indexes where each column value is between min & max
perc_limit = 1.5 # Guideline: Set to 1 + absolute value of (max of 25%/75% percentiles)

"""
# ------ APPROACH 1: REQUIRES PERFECT MATCHING. DOES NOT SCALE WELL IF  ATTRIBUTE HAS > 20 UNIQUE VALUES
# Only works if the numeric cols are the same scale e.g. Percentages
chosen_idx_list = []
for col in forecastdf_dummy_agg.select_dtypes('number').columns:
    chosen_idx_list.append(pd.DataFrame(forecastdf_dummy_agg[abs(forecastdf_dummy_agg[col]) <= perc_limit].index, index=forecastdf_dummy_agg[abs(forecastdf_dummy_agg[col]) <= perc_limit].index))
# Selects only the indices that match across all the columns
forecastdf_dummy_agg_filtered = forecastdf_dummy_agg.iloc[
    pd.concat([k for k in chosen_idx_list], axis=1, join='inner').iloc[:,0].index]
"""

# ------ APPROACH 2: REPLACE WITH NA WHICH REGRESSION MODEL WILL IMPUTE
forecastdf_dummy_agg_filtered = forecastdf_dummy_agg.copy()
for col in forecastdf_dummy_agg.select_dtypes('number').columns:
    forecastdf_dummy_agg_filtered.loc[abs(forecastdf_dummy_agg_filtered[col]) > perc_limit, col] = np.nan
    
# Drop rows where all values are NA
forecastdf_dummy_agg_filtered.dropna(axis=0, how='all')
#Interpolate NA rows based on time series
forecastdf_dummy_agg_filtered = forecastdf_dummy_agg_filtered.sort_values(by=['Retailer','ds']).set_index('ds').interpolate(method='time').reset_index().dropna()
forecastdf_dummy_agg_filtered.describe()
# Out:
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                        522.00
# mean                                           0.02
# std                                            0.43
# min                                           -0.94
# 25%                                           -0.16
# 50%                                           -0.00
# 75%                                            0.14
# max                                            1.48
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                         522.00
# mean                                            0.00
# std                                             0.06
# min                                            -0.30
# 25%                                            -0.01
# 50%                                            -0.00
# 75%                                             0.00
# max                                             0.73
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                        522.00
# mean                                          -0.03
# std                                            0.52
# min                                           -1.49
# 25%                                           -0.18
# 50%                                           -0.01
# 75%                                            0.16
# max                                            1.50
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                         522.00
# mean                                            0.00
# std                                             0.09
# min                                            -0.31
# 25%                                            -0.02
# 50%                                            -0.00
# 75%                                             0.01
# max                                             0.73
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.21
# min                                                -0.55
# 25%                                                -0.11
# 50%                                                -0.01
# 75%                                                 0.10
# max                                                 1.43
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.04
# min                                                -0.37
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.20
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             522.00
# mean                                               -0.01
# std                                                 0.25
# min                                                -1.48
# 25%                                                -0.12
# 50%                                                -0.00
# 75%                                                 0.10
# max                                                 1.23
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             522.00
# mean                                               -0.01
# std                                                 0.07
# min                                                -0.37
# 25%                                                -0.02
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 0.34
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             522.00
# mean                                                0.03
# std                                                 0.22
# min                                                -0.60
# 25%                                                -0.05
# 50%                                                 0.00
# 75%                                                 0.07
# max                                                 1.19
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.12
# min                                                -0.13
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 1.42
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             522.00
# mean                                                0.02
# std                                                 0.29
# min                                                -1.15
# 25%                                                -0.05
# 50%                                                 0.00
# 75%                                                 0.09
# max                                                 1.31
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             522.00
# mean                                                0.02
# std                                                 0.18
# min                                                -0.20
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 1.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             522.00
# mean                                                0.02
# std                                                 0.47
# min                                                -0.86
# 25%                                                -0.23
# 50%                                                -0.01
# 75%                                                 0.19
# max                                                 1.47
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.06
# min                                                -0.65
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.27
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             522.00
# mean                                               -0.02
# std                                                 0.53
# min                                                -1.47
# 25%                                                -0.19
# 50%                                                -0.01
# 75%                                                 0.18
# max                                                 1.45
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.09
# min                                                -0.66
# 25%                                                -0.03
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 0.51
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             522.00
# mean                                                0.03
# std                                                 0.25
# min                                                -0.58
# 25%                                                -0.10
# 50%                                                -0.00
# 75%                                                 0.12
# max                                                 1.14
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.09
# min                                                -0.11
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 1.43
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.33
# min                                                -1.25
# 25%                                                -0.11
# 50%                                                -0.00
# 75%                                                 0.14
# max                                                 1.26
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.11
# min                                                -0.16
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 1.26
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.18
# min                                                -0.85
# 25%                                                -0.06
# 50%                                                 0.00
# 75%                                                 0.06
# max                                                 0.97
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.05
# min                                                -0.53
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.24
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.23
# min                                                -1.04
# 25%                                                -0.06
# 50%                                                 0.01
# 75%                                                 0.07
# max                                                 0.88
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.07
# min                                                -0.54
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 0.43
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - PEPSI & AO BRANDS  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.37
# min                                                -0.75
# 25%                                                -0.18
# 50%                                                -0.01
# 75%                                                 0.13
# max                                                 1.49
#
#        ...  dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - LIGHT  \
# count  ...                                             522.00
# mean   ...                                               0.02
# std    ...                                               0.17
# min    ...                                              -1.29
# 25%    ...                                              -0.02
# 50%    ...                                              -0.00
# 75%    ...                                               0.01
# max    ...                                               1.45
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             522.00
# mean                                                0.04
# std                                                 0.33
# min                                                -0.84
# 25%                                                -0.13
# 50%                                                -0.00
# 75%                                                 0.13
# max                                                 1.34
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.03
# min                                                -0.15
# 25%                                                -0.02
# 50%                                                -0.01
# 75%                                                 0.00
# max                                                 0.19
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.40
# min                                                -1.42
# 25%                                                -0.14
# 50%                                                 0.00
# 75%                                                 0.13
# max                                                 1.45
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             522.00
# mean                                               -0.01
# std                                                 0.05
# min                                                -0.41
# 25%                                                -0.03
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 0.22
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             522.00
# mean                                               -0.10
# std                                                 0.54
# min                                                -0.92
# 25%                                                -0.55
# 50%                                                -0.08
# 75%                                                 0.09
# max                                                 1.47
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.08
# min                                                -0.55
# 25%                                                -0.02
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.56
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             522.00
# mean                                                0.06
# std                                                 0.59
# min                                                -1.47
# 25%                                                -0.18
# 50%                                                 0.02
# 75%                                                 0.34
# max                                                 1.48
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.12
# min                                                -0.55
# 25%                                                -0.04
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.56
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             522.00
# mean                                               -0.03
# std                                                 0.32
# min                                                -0.90
# 25%                                                -0.09
# 50%                                                -0.01
# 75%                                                 0.06
# max                                                 1.47
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.05
# min                                                -0.32
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.44
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             522.00
# mean                                               -0.02
# std                                                 0.36
# min                                                -1.42
# 25%                                                -0.09
# 50%                                                -0.01
# 75%                                                 0.07
# max                                                 1.48
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.09
# min                                                -0.44
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 1.18
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             522.00
# mean                                               -0.04
# std                                                 0.38
# min                                                -0.85
# 25%                                                -0.12
# 50%                                                -0.01
# 75%                                                 0.06
# max                                                 1.50
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.06
# min                                                -0.21
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 1.05
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             522.00
# mean                                                0.02
# std                                                 0.37
# min                                                -1.44
# 25%                                                -0.09
# 50%                                                -0.00
# 75%                                                 0.11
# max                                                 1.41
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             522.00
# mean                                                0.00
# std                                                 0.09
# min                                                -0.21
# 25%                                                -0.02
# 50%                                                -0.01
# 75%                                                 0.01
# max                                                 1.05
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             522.00
# mean                                               -0.07
# std                                                 0.48
# min                                                -0.89
# 25%                                                -0.47
# 50%                                                -0.02
# 75%                                                 0.11
# max                                                 1.44
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.04
# min                                                -0.29
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.45
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.53
# min                                                -1.37
# 25%                                                -0.17
# 50%                                                 0.00
# 75%                                                 0.16
# max                                                 1.49
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             522.00
# mean                                               -0.00
# std                                                 0.07
# min                                                -0.29
# 25%                                                -0.02
# 50%                                                -0.00
# 75%                                                 0.01
# max                                                 0.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             522.00
# mean                                                0.01
# std                                                 0.13
# min                                                -0.38
# 25%                                                -0.04
# 50%                                                 0.00
# 75%                                                 0.05
# max                                                 1.33
#
#        dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             522.00
# mean                                                0.00
# std                                                 0.07
# min                                                -0.14
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.94
#
#        val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# count                                             522.00
# mean                                                0.00
# std                                                 0.13
# min                                                -0.66
# 25%                                                -0.05
# 50%                                                 0.00
# 75%                                                 0.06
# max                                                 1.21
#
#        dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK
# count                                             522.00
# mean                                                0.01
# std                                                 0.10
# min                                                -0.19
# 25%                                                -0.01
# 50%                                                -0.00
# 75%                                                 0.00
# max                                                 0.92
#
# [8 rows x 172 columns]

# %%
# Run as is
perc_rows_selected = forecastdf_dummy_agg_filtered['ds'].count() / forecastdf_dummy_agg['ds'].count()
print(f"Selected {perc_rows_selected*100: .2f}% of the dataset rows for regression \n")
print(f"as these have less than a {perc_limit*100: .2f}% swing in value vs. prior period")
# Out:
# Selected  99.43% of the dataset rows for regression
#
# as these have less than a  150.00% swing in value vs. prior period

# %%
# Run as is
# Create actual regression datasets
regression_df = forecastdf_dummy_agg_filtered.loc[:, 
                                     ['Retailer','ds'] + 
                                     forecastdf_dummy_agg_filtered.columns[
                                         forecastdf_dummy_agg_filtered.columns.str.contains('perc') & 
                                         # ensure line below has your attribute name
                                         forecastdf_dummy_agg_filtered.columns.str.contains(FOCUS_ATTRIBUTE_COLUMN)
                                     ].to_flat_index().to_list()].reset_index(drop=True)

# Split datasets
regression_df = regression_df.loc[:,~regression_df.columns.duplicated()] # Drop duplicate columns

## Categorical column transformations
# Encodes the categorical columns as strings so they can work with xgboost
regression_df['ds_month'] = regression_df['ds'].dt.month
regression_df['ds_year'] = regression_df['ds'].dt.year
# Note: LabelEncoder encodes a cardinal order e.g. 1>2>3 - Relevant for dates
lbl_month = LabelEncoder()
regression_df['ds_month'] = lbl_month.fit_transform(regression_df['ds_month'].astype(str))
lbl_year = LabelEncoder()
regression_df['ds_year'] = lbl_year.fit_transform(regression_df['ds_year'].astype(str))
# Onehot encode Market label & drops it from set
regression_df = pd.get_dummies(regression_df, columns=['Retailer'])  

# Create train & test dfs
regression_df = regression_df.drop('ds', axis=1)
regression_df_train = regression_df.sample(frac=0.8, random_state=42) # Selects 80% of dataset for main training
regression_df_test = regression_df.drop(regression_df_train.index) # Selects remainder of dataset for sight-unseen testing
regression_df_train.reset_index(drop=True, inplace=True)
regression_df_test.reset_index(drop=True, inplace=True)
regression_df_train
# Out:
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# 0                                            0.06
# 1                                           -0.60
# 2                                           -0.02
# 3                                            0.09
# 4                                           -0.11
# ..                                            ...
# 413                                          0.04
# 414                                          0.12
# 415                                          0.67
# 416                                          0.33
# 417                                          0.08
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# 0                                            -0.02
# 1                                            -0.07
# 2                                            -0.01
# 3                                             0.03
# 4                                             0.01
# ..                                             ...
# 413                                          -0.01
# 414                                          -0.01
# 415                                           0.18
# 416                                           0.01
# 417                                          -0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# 0                                            0.00
# 1                                           -0.64
# 2                                            0.01
# 3                                            0.04
# 4                                           -0.07
# ..                                            ...
# 413                                          0.01
# 414                                         -0.03
# 415                                         -0.98
# 416                                          0.53
# 417                                          0.18
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# 0                                            -0.08
# 1                                            -0.05
# 2                                            -0.01
# 3                                             0.02
# 4                                            -0.00
# ..                                             ...
# 413                                          -0.01
# 414                                           0.06
# 415                                           0.22
# 416                                           0.00
# 417                                          -0.01
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# 0                                                 0.01
# 1                                                -0.03
# 2                                                -0.25
# 3                                                -0.12
# 4                                                -0.12
# ..                                                 ...
# 413                                              -0.11
# 414                                               0.18
# 415                                              -0.27
# 416                                              -0.11
# 417                                               0.01
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# 0                                                -0.01
# 1                                                 0.02
# 2                                                -0.08
# 3                                                -0.01
# 4                                                 0.03
# ..                                                 ...
# 413                                               0.06
# 414                                               0.01
# 415                                               0.06
# 416                                               0.00
# 417                                               0.02
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# 0                                                 0.04
# 1                                                 0.03
# 2                                                -0.30
# 3                                                 0.02
# 4                                                -0.32
# ..                                                 ...
# 413                                              -0.09
# 414                                               0.18
# 415                                              -0.38
# 416                                               0.10
# 417                                              -0.10
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# 0                                                -0.03
# 1                                                -0.01
# 2                                                -0.09
# 3                                                -0.04
# 4                                                 0.01
# ..                                                 ...
# 413                                               0.01
# 414                                               0.14
# 415                                               0.07
# 416                                              -0.01
# 417                                               0.02
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# 0                                                 0.22
# 1                                                 0.09
# 2                                                 0.04
# 3                                                 0.06
# 4                                                -0.05
# ..                                                 ...
# 413                                               0.05
# 414                                              -0.09
# 415                                               0.01
# 416                                               0.09
# 417                                               0.01
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# 0                                                -0.07
# 1                                                -0.01
# 2                                                 0.00
# 3                                                 0.09
# 4                                                 0.01
# ..                                                 ...
# 413                                              -0.00
# 414                                              -0.03
# 415                                               0.04
# 416                                              -0.00
# 417                                               0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# 0                                                -0.32
# 1                                                -0.55
# 2                                                 0.01
# 3                                                -0.01
# 4                                                -0.04
# ..                                                 ...
# 413                                               0.04
# 414                                              -0.18
# 415                                               0.10
# 416                                               0.17
# 417                                               0.11
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# 0                                                 0.09
# 1                                                -0.01
# 2                                                -0.00
# 3                                                 0.08
# 4                                                 0.00
# ..                                                 ...
# 413                                               0.00
# 414                                              -0.08
# 415                                               0.23
# 416                                              -0.01
# 417                                               0.01
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# 0                                                 1.06
# 1                                                 0.69
# 2                                                 0.02
# 3                                                 1.23
# 4                                                 0.88
# ..                                                 ...
# 413                                               0.01
# 414                                               1.04
# 415                                               0.08
# 416                                               0.21
# 417                                              -0.10
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# 0                                                -0.01
# 1                                                 0.03
# 2                                                 0.00
# 3                                                 0.02
# 4                                                 0.02
# ..                                                 ...
# 413                                               0.00
# 414                                              -0.12
# 415                                               0.27
# 416                                               0.00
# 417                                               0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# 0                                                -0.03
# 1                                                -0.59
# 2                                                 0.01
# 3                                                 0.27
# 4                                                 1.02
# ..                                                 ...
# 413                                              -0.01
# 414                                              -0.13
# 415                                               0.05
# 416                                               0.76
# 417                                              -0.10
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# 0                                                -0.10
# 1                                                 0.10
# 2                                                 0.00
# 3                                                 0.05
# 4                                                 0.12
# ..                                                 ...
# 413                                              -0.00
# 414                                              -0.06
# 415                                               0.41
# 416                                               0.00
# 417                                               0.00
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# 0                                                 0.01
# 1                                                -0.24
# 2                                                -0.28
# 3                                                -0.09
# 4                                                 0.08
# ..                                                 ...
# 413                                              -0.03
# 414                                              -0.44
# 415                                               0.30
# 416                                               0.69
# 417                                               0.04
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# 0                                                -0.00
# 1                                                -0.00
# 2                                                -0.03
# 3                                                -0.00
# 4                                                 0.11
# ..                                                 ...
# 413                                               0.04
# 414                                              -0.10
# 415                                               0.06
# 416                                               0.00
# 417                                              -0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# 0                                                 0.01
# 1                                                -0.03
# 2                                                -0.19
# 3                                                -0.02
# 4                                                -0.03
# ..                                                 ...
# 413                                              -0.03
# 414                                              -0.19
# 415                                               0.39
# 416                                               1.01
# 417                                               0.01
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# 0                                                -0.02
# 1                                                -0.02
# 2                                                -0.03
# 3                                                -0.04
# 4                                                 0.10
# ..                                                 ...
# 413                                               0.02
# 414                                              -0.10
# 415                                               0.12
# 416                                               0.00
# 417                                              -0.00
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# 0                                                 0.20
# 1                                                 0.07
# 2                                                 0.03
# 3                                                 0.01
# 4                                                -0.03
# ..                                                 ...
# 413                                               0.06
# 414                                              -0.14
# 415                                              -0.04
# 416                                               0.05
# 417                                               0.03
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# 0                                                 0.13
# 1                                                -0.01
# 2                                                -0.00
# 3                                                 0.02
# 4                                                 0.01
# ..                                                 ...
# 413                                              -0.00
# 414                                               0.22
# 415                                               0.00
# 416                                               0.00
# 417                                               0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# 0                                                -0.10
# 1                                                -0.36
# 2                                                -0.00
# 3                                                -0.00
# 4                                                -0.03
# ..                                                 ...
# 413                                               0.06
# 414                                              -0.21
# 415                                              -0.05
# 416                                               0.15
# 417                                               0.15
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# 0                                                 0.16
# 1                                                -0.01
# 2                                                 0.00
# 3                                                 0.01
# 4                                                -0.00
# ..                                                 ...
# 413                                              -0.00
# 414                                               0.17
# 415                                               0.03
# 416                                               0.00
# 417                                               0.00
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - PEPSI & AO BRANDS  ...  \
# 0                                                 0.19                    ...
# 1                                                 0.52                    ...
# 2                                                -0.26                    ...
# 3                                                 1.47                    ...
# 4                                                 0.69                    ...
# ..                                                 ...                    ...
# 413                                               0.05                    ...
# 414                                               0.37                    ...
# 415                                               0.04                    ...
# 416                                               0.15                    ...
# 417                                              -0.22                    ...
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# 0                                                -0.01
# 1                                                -0.85
# 2                                                 0.82
# 3                                                 0.21
# 4                                                -0.16
# ..                                                 ...
# 413                                               0.05
# 414                                               0.13
# 415                                               0.23
# 416                                              -0.66
# 417                                               0.19
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# 0                                                -0.02
# 1                                                -0.01
# 2                                                 0.00
# 3                                                -0.00
# 4                                                -0.01
# ..                                                 ...
# 413                                              -0.00
# 414                                              -0.14
# 415                                              -0.01
# 416                                               0.00
# 417                                               0.03
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# 0                                                 0.15
# 1                                                -0.02
# 2                                                -0.08
# 3                                                -0.26
# 4                                                 0.04
# ..                                                 ...
# 413                                               0.04
# 414                                              -0.51
# 415                                               0.22
# 416                                               0.38
# 417                                               0.00
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# 0                                                -0.01
# 1                                                -0.02
# 2                                                -0.03
# 3                                                 0.00
# 4                                                 0.01
# ..                                                 ...
# 413                                               0.00
# 414                                              -0.18
# 415                                              -0.32
# 416                                               0.01
# 417                                               0.01
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# 0                                                 0.12
# 1                                                 0.02
# 2                                                 0.05
# 3                                                 0.08
# 4                                                 0.01
# ..                                                 ...
# 413                                               0.02
# 414                                              -0.63
# 415                                               0.12
# 416                                               0.43
# 417                                               0.08
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# 0                                                -0.01
# 1                                                -0.05
# 2                                                -0.08
# 3                                                 0.01
# 4                                                -0.01
# ..                                                 ...
# 413                                               0.00
# 414                                              -0.20
# 415                                              -0.44
# 416                                               0.00
# 417                                               0.01
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# 0                                                 0.02
# 1                                                 0.01
# 2                                                 0.18
# 3                                                -0.10
# 4                                                -0.33
# ..                                                 ...
# 413                                               0.05
# 414                                              -0.08
# 415                                              -0.53
# 416                                               0.23
# 417                                              -0.06
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# 0                                                -0.03
# 1                                                -0.01
# 2                                                -0.05
# 3                                                -0.01
# 4                                                 0.04
# ..                                                 ...
# 413                                              -0.01
# 414                                               0.02
# 415                                               0.08
# 416                                              -0.01
# 417                                              -0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# 0                                                 0.19
# 1                                                -0.00
# 2                                                -0.17
# 3                                                -0.02
# 4                                                -0.13
# ..                                                 ...
# 413                                               0.06
# 414                                              -0.20
# 415                                              -0.19
# 416                                               0.33
# 417                                              -0.36
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# 0                                                -0.07
# 1                                                -0.03
# 2                                                -0.10
# 3                                                -0.00
# 4                                                 0.03
# ..                                                 ...
# 413                                              -0.03
# 414                                               0.06
# 415                                               0.09
# 416                                              -0.01
# 417                                              -0.01
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# 0                                                 0.02
# 1                                                -0.02
# 2                                                -0.40
# 3                                                 0.22
# 4                                                -0.35
# ..                                                 ...
# 413                                               0.05
# 414                                              -0.07
# 415                                              -0.82
# 416                                              -0.80
# 417                                               0.01
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# 0                                                -0.02
# 1                                                 0.01
# 2                                                -0.03
# 3                                                -0.01
# 4                                                 0.01
# ..                                                 ...
# 413                                              -0.01
# 414                                              -0.04
# 415                                               0.06
# 416                                               0.05
# 417                                               0.05
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# 0                                                 0.06
# 1                                                 0.09
# 2                                                -0.02
# 3                                                 0.03
# 4                                                -0.21
# ..                                                 ...
# 413                                               0.07
# 414                                              -0.08
# 415                                              -0.54
# 416                                               0.58
# 417                                              -0.11
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# 0                                                -0.02
# 1                                                -0.00
# 2                                                -0.08
# 3                                                -0.01
# 4                                                -0.01
# ..                                                 ...
# 413                                              -0.02
# 414                                              -0.07
# 415                                               0.07
# 416                                               0.14
# 417                                               0.05
#
#      val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# 0                                                 0.02
# 1                                                 0.00
# 2                                                 0.01
# 3                                                -0.08
# 4                                                -0.15
# ..                                                 ...
# 413                                               0.04
# 414                                              -0.06
# 415                                               0.09
# 416                                               0.10
# 417                                               0.02
#
#      dist_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# 0                                                -0.09
# 1                                                 0.01
# 2                                                -0.05
# 3                                                -0.03
# 4                                                 0.22
# ..                                                 ...
# 413                                              -0.00
# 414                                               0.00
# 415                                               0.00
# 416                                              -0.00
# 417                                              -0.00
#
#      val_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  \
# 0                                                 0.10
# 1                                                -0.03
# 2                                                 0.02
# 3                                                -0.13
# 4                                                -0.27
# ..                                                 ...
# 413                                               0.03
# 414                                              -0.09
# 415                                              -0.05
# 416                                               0.17
# 417                                               0.06
#
#      dist_chg2_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK  ds_month  \
# 0                                                -0.00                    4
# 1                                                 0.00                    5
# 2                                                -0.11                    3
# 3                                                -0.03                    7
# 4                                                 0.21                    7
# ..                                                 ...                  ...
# 413                                              -0.01                    4
# 414                                               0.01                    9
# 415                                               0.00                    8
# 416                                              -0.00                    6
# 417                                              -0.00                    7
#
#      ds_year  Retailer_Albert Heijn  Retailer_Hoogvliet  Retailer_Jumbo  \
# 0          1                      0                   0               0
# 1          1                      0                   0               0
# 2          0                      1                   0               0
# 3          2                      0                   1               0
# 4          2                      1                   0               0
# ..       ...                    ...                 ...             ...
# 413        2                      0                   0               1
# 414        1                      0                   0               0
# 415        1                      0                   0               0
# 416        1                      0                   0               0
# 417        1                      0                   0               1
#
#      Retailer_Plus  Retailer_Vomar
# 0                0               1
# 1                0               1
# 2                0               0
# 3                0               0
# 4                0               0
# ..             ...             ...
# 413              0               0
# 414              0               1
# 415              0               1
# 416              1               0
# 417              0               0
#
# [418 rows x 179 columns]

# %% [markdown]
# We will predict the transferable demand for each of these columns below in turn

# %%
# Run as is
prediction_cols = regression_df_train.columns[
    (regression_df_train.columns.str.contains('val_chg1')) & 
    (regression_df_train.columns.str.contains(FOCUS_ATTRIBUTE_COLUMN))].to_flat_index().to_list()
regression_df_train[prediction_cols].describe()
# Out:
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_AO SEGMENTS  \
# count                                        418.00
# mean                                           0.02
# std                                            0.43
# min                                           -0.80
# 25%                                           -0.16
# 50%                                           -0.00
# 75%                                            0.14
# max                                            1.48
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - COCA COLA & AO BRANDS  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.21
# min                                                -0.55
# 25%                                                -0.12
# 50%                                                -0.01
# 75%                                                 0.10
# max                                                 1.43
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - EIGEN MERK  \
# count                                             418.00
# mean                                                0.02
# std                                                 0.23
# min                                                -0.60
# 25%                                                -0.06
# 50%                                                 0.00
# 75%                                                 0.06
# max                                                 1.19
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - LIGHT - PEPSI  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.47
# min                                                -0.83
# 25%                                                -0.22
# 50%                                                -0.01
# 75%                                                 0.19
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - COCA COLA  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.24
# min                                                -0.58
# 25%                                                -0.10
# 50%                                                 0.00
# 75%                                                 0.12
# max                                                 1.00
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - EIGEN MERK  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.18
# min                                                -0.79
# 25%                                                -0.06
# 50%                                                 0.01
# 75%                                                 0.06
# max                                                 0.97
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - REGULAR - PEPSI & AO BRANDS  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.37
# min                                                -0.75
# 25%                                                -0.16
# 50%                                                -0.00
# 75%                                                 0.14
# max                                                 1.49
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_COLA - ZERO - COCA COLA  \
# count                                             418.00
# mean                                                0.05
# std                                                 0.29
# min                                                -0.66
# 25%                                                -0.11
# 50%                                                 0.01
# 75%                                                 0.15
# max                                                 1.31
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ENERGY - AO BRANDS  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.09
# min                                                -0.36
# 25%                                                -0.04
# 50%                                                -0.00
# 75%                                                 0.04
# max                                                 0.58
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ENERGY - RED BULL  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.20
# min                                                -0.80
# 25%                                                -0.07
# 50%                                                -0.01
# 75%                                                 0.07
# max                                                 1.20
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_BLACK - CAN  \
# count                                             418.00
# mean                                               -0.01
# std                                                 0.37
# min                                                -0.99
# 25%                                                -0.17
# 50%                                                -0.01
# 75%                                                 0.11
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_BLACK - CARTON  \
# count                                             418.00
# mean                                                0.06
# std                                                 0.39
# min                                                -0.74
# 25%                                                -0.20
# 50%                                                 0.01
# 75%                                                 0.26
# max                                                 1.49
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_BLACK - PET MULTISERVE  \
# count                                             418.00
# mean                                               -0.01
# std                                                 0.48
# min                                                -0.83
# 25%                                                -0.38
# 50%                                                -0.01
# 75%                                                 0.18
# max                                                 1.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_BLACK - PET SINGLESERVE  \
# count                                             418.00
# mean                                                0.06
# std                                                 0.41
# min                                                -0.81
# 25%                                                -0.14
# 50%                                                 0.02
# 75%                                                 0.18
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_GREEN - CAN  \
# count                                             418.00
# mean                                                0.00
# std                                                 0.34
# min                                                -0.99
# 25%                                                -0.16
# 50%                                                -0.01
# 75%                                                 0.12
# max                                                 1.45
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_GREEN - CARTON  \
# count                                             418.00
# mean                                                0.09
# std                                                 0.51
# min                                                -0.73
# 25%                                                -0.25
# 50%                                                 0.01
# 75%                                                 0.33
# max                                                 1.48
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_GREEN - PET MULTISERVE  \
# count                                             418.00
# mean                                               -0.00
# std                                                 0.51
# min                                                -0.89
# 25%                                                -0.41
# 50%                                                -0.03
# 75%                                                 0.23
# max                                                 1.49
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ICE_TEA_GREEN - PET SINGLESERVE  \
# count                                             418.00
# mean                                                0.05
# std                                                 0.39
# min                                                -0.76
# 25%                                                -0.15
# 50%                                                 0.01
# 75%                                                 0.20
# max                                                 1.49
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_LEMON_LIME  \
# count                                       418.00
# mean                                          0.05
# std                                           0.28
# min                                          -0.61
# 25%                                          -0.11
# 50%                                           0.02
# 75%                                           0.17
# max                                           1.23
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_MINERAALWATER - PET MULTISERVE & AO PACK FORMATS  \
# count                                             418.00
# mean                                                0.02
# std                                                 0.15
# min                                                -0.32
# 25%                                                -0.05
# 50%                                                 0.01
# 75%                                                 0.08
# max                                                 1.48
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_MINERAALWATER - PET SINGLESERVE  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.14
# min                                                -0.44
# 25%                                                -0.06
# 50%                                                 0.00
# 75%                                                 0.08
# max                                                 0.58
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_ORANGE  \
# count                                   418.00
# mean                                      0.02
# std                                       0.19
# min                                      -0.46
# 25%                                      -0.10
# 50%                                       0.01
# 75%                                       0.12
# max                                       0.97
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - LIGHT - AO BRANDS  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.34
# min                                                -0.90
# 25%                                                -0.12
# 50%                                                -0.01
# 75%                                                 0.12
# max                                                 1.50
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - LIGHT - CRYSTAL CL  \
# count                                             418.00
# mean                                               -0.03
# std                                                 0.42
# min                                                -0.86
# 25%                                                -0.17
# 50%                                                 0.01
# 75%                                                 0.10
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - LIGHT - EIGEN MERK  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.12
# min                                                -0.54
# 25%                                                -0.05
# 50%                                                 0.01
# 75%                                                 0.07
# max                                                 0.53
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - LIGHT - SPA  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.44
# min                                                -0.82
# 25%                                                -0.14
# 50%                                                -0.01
# 75%                                                 0.13
# max                                                 1.48
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - REGULAR - AO BRANDS  \
# count                                             418.00
# mean                                                0.00
# std                                                 0.14
# min                                                -0.42
# 25%                                                -0.08
# 50%                                                -0.00
# 75%                                                 0.07
# max                                                 0.59
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - REGULAR - FERNANDES  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.36
# min                                                -0.82
# 25%                                                -0.09
# 50%                                                -0.00
# 75%                                                 0.09
# max                                                 1.43
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.GAZEUSES - REGULAR - RIVELLA  \
# count                                             418.00
# mean                                                0.03
# std                                                 0.49
# min                                                -0.82
# 25%                                                -0.23
# 50%                                                -0.00
# 75%                                                 0.14
# max                                                 1.50
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.VRUCHT.LIM. - LIGHT  \
# count                                             418.00
# mean                                                0.06
# std                                                 0.33
# min                                                -0.64
# 25%                                                -0.11
# 50%                                                 0.00
# 75%                                                 0.17
# max                                                 1.41
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             418.00
# mean                                                0.04
# std                                                 0.29
# min                                                -0.71
# 25%                                                -0.11
# 50%                                                 0.00
# 75%                                                 0.14
# max                                                 1.48
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.VRUCHT.LIM. - REGULAR - EIGEN MERK  \
# count                                             418.00
# mean                                                0.01
# std                                                 0.13
# min                                                -0.81
# 25%                                                -0.05
# 50%                                                 0.01
# 75%                                                 0.07
# max                                                 0.64
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.VRUCHT.LIM. - REGULAR - HERO  \
# count                                             418.00
# mean                                               -0.02
# std                                                 0.32
# min                                                -0.88
# 25%                                                -0.08
# 50%                                                -0.00
# 75%                                                 0.07
# max                                                 1.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_OV.VRUCHT.LIM. - REGULAR - SPA  \
# count                                             418.00
# mean                                               -0.04
# std                                                 0.38
# min                                                -0.90
# 25%                                                -0.15
# 50%                                                -0.01
# 75%                                                 0.07
# max                                                 1.45
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_SPORT  \
# count                                  418.00
# mean                                     0.02
# std                                      0.17
# min                                     -0.60
# 25%                                     -0.08
# 50%                                      0.00
# 75%                                      0.09
# max                                      1.43
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_TONIC  \
# count                                  418.00
# mean                                     0.07
# std                                      0.43
# min                                     -0.74
# 25%                                     -0.14
# 50%                                      0.01
# 75%                                      0.21
# max                                      1.46
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - LIGHT  \
# count                                             418.00
# mean                                               -0.05
# std                                                 0.49
# min                                                -1.00
# 25%                                                -0.42
# 50%                                                -0.03
# 75%                                                 0.14
# max                                                 1.49
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - AO BRANDS  \
# count                                             418.00
# mean                                                0.04
# std                                                 0.33
# min                                                -0.84
# 25%                                                -0.13
# 50%                                                -0.00
# 75%                                                 0.13
# max                                                 1.34
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - DUBBEL FRISS  \
# count                                             418.00
# mean                                               -0.11
# std                                                 0.53
# min                                                -0.92
# 25%                                                -0.57
# 50%                                                -0.08
# 75%                                                 0.08
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHT.LIM. - REGULAR - ROOSVICEE  \
# count                                             418.00
# mean                                               -0.04
# std                                                 0.32
# min                                                -0.90
# 25%                                                -0.09
# 50%                                                -0.02
# 75%                                                 0.05
# max                                                 1.47
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - AO BRANDS  \
# count                                             418.00
# mean                                               -0.04
# std                                                 0.39
# min                                                -0.84
# 25%                                                -0.15
# 50%                                                -0.01
# 75%                                                 0.06
# max                                                 1.50
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - APPELSIENTJE  \
# count                                             418.00
# mean                                               -0.07
# std                                                 0.48
# min                                                -0.89
# 25%                                                -0.47
# 50%                                                -0.02
# 75%                                                 0.09
# max                                                 1.44
#
#        val_chg1_perc_SEG_DESC_ATTRIBUTE_VRUCHTENDRANK - EIGEN MERK
# count                                             418.00
# mean                                                0.01
# std                                                 0.12
# min                                                -0.38
# 25%                                                -0.04
# 50%                                                 0.00
# 75%                                                 0.04
# max                                                 1.33

# %%
# Run as is
## Bayes Robust Approach
final_coefs_dict = {} # defaultdict(pd.DataFrame)
final_scores_dict = {}

for col in prediction_cols:
    my_param_grid = {
        'tol':[1e-3, 1e-4],
        'alpha_1':[1e-6, 1e-8, 1e-4],
        'lambda_init':[1, 0.5, 10]    
    }
    reg_train_pipe = Pipeline([
        ('transformer', QuantileTransformer(output_distribution='normal')),
        ('model', GridSearchCV(BayesianRidge(n_iter=500, fit_intercept=True), 
                                    param_grid=my_param_grid, scoring='r2', n_jobs=-1))
    ])
    clf = reg_train_pipe.fit(regression_df_train.drop(col, axis=1), regression_df_train.loc[:,col])
    myscore = clf.score(regression_df_test.drop(col, axis=1), regression_df_test.loc[:,col])
    final_scores_dict[col] = pd.DataFrame(pd.Series(myscore, index=[col],name='Score'))
    temp_coefs_df = pd.DataFrame(list(zip(regression_df_train.drop(col, axis=1).columns, clf['model'].best_estimator_.coef_)), columns=['Feature','Coefficient'])
    # Select only the dist_chg numbers
    final_coefs_dict[col] = temp_coefs_df.loc[
        temp_coefs_df['Feature'].str.contains(FOCUS_ATTRIBUTE_COLUMN) & 
        temp_coefs_df['Feature'].str.contains('dist_chg1')].copy()
# Out:
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# C:\Users\trainor-gilhamt\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2612: UserWarning: n_quantiles (1000) is greater than the total number of samples (418). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "

# %%
final_coefs = pd.DataFrame()
final_scores = pd.DataFrame()

for k in final_coefs_dict.keys():
    final_coefs_dict[k].loc[:,'TO_ATTRIBUTE'] = k # Set the key as a column in the dataframe
    final_coefs = final_coefs.append(final_coefs_dict[k].copy(), ignore_index=True)
    
    final_scores_dict[k].loc[:,'MODEL_NAME'] = k # Set the key as a column in the dataframe
    final_scores = final_scores.append(final_scores_dict[k])

# Create final accuracy scores
final_scores['MODEL_NAME'] = final_scores['MODEL_NAME'].str.replace("val_chg1_perc_","").str.replace(FOCUS_ATTRIBUTE_COLUMN+"_","")
final_scores_bayes = final_scores.copy()

# Format & adjust coefs
final_coefs.rename(columns={'Feature':'FROM_ATTRIBUTE'}, inplace=True)

final_coefs['TO_ATTRIBUTE'] = final_coefs['TO_ATTRIBUTE'].str.replace("val_chg1_perc_","").str.replace(FOCUS_ATTRIBUTE_COLUMN+"_","")
final_coefs['FROM_ATTRIBUTE'] = final_coefs['FROM_ATTRIBUTE'].str.replace("dist_chg1_perc_","").str.replace(FOCUS_ATTRIBUTE_COLUMN+"_",'')

"""
# Keep self interaction by ensuring it is negative i.e. substitute
#final_coefs.loc[(final_coefs['TO_ATTRIBUTE'] == final_coefs['FROM_ATTRIBUTE']) & 
#                (final_coefs['Coefficient']>0), 'Coefficient'] = final_coefs.loc[(final_coefs['TO_ATTRIBUTE'] == final_coefs['FROM_ATTRIBUTE']) & 
#                                                                                 (final_coefs['Coefficient']>0), 'Coefficient'] * -1
# For ISD, remove self elasts
final_coefs = final_coefs.loc[~(final_coefs['TO_ATTRIBUTE'] == final_coefs['FROM_ATTRIBUTE'])]
                              
# Zero out positive coefficients i.e. Increase Dist -> Increase value: Implies complements vs. substitutes
final_coefs.loc[final_coefs['Coefficient'] > 0, 'Coefficient'] = 0

# Adjust final coefficients for export

# Rebase % transfers to 100%
final_coefs_adjusted_bayes = final_coefs.merge(
    final_coefs[['TO_ATTRIBUTE','Coefficient']].groupby(['TO_ATTRIBUTE']).sum(), 
    on=['TO_ATTRIBUTE'], suffixes=("","_sum")
)

final_coefs_adjusted_bayes.loc[:, 'Percent_Transfer'] = final_coefs_adjusted_bayes['Coefficient'] / final_coefs_adjusted_bayes['Coefficient_sum']
final_coefs_adjusted_bayes[['TO_ATTRIBUTE','FROM_ATTRIBUTE','Percent_Transfer']].sort_values(['TO_ATTRIBUTE','Percent_Transfer'], ascending=False)
"""
# For ISD, remove self elasts
final_coefs = final_coefs.loc[~(final_coefs['TO_ATTRIBUTE'] == final_coefs['FROM_ATTRIBUTE'])]

# Invert the scale so the substitutes (-ve coeff) are now positives
final_coefs.loc[:,'Coefficient'] = final_coefs.loc[:,'Coefficient'] *-1

# Finalise Percent Transfer by abs-value shift to account for -ve coefficients
# Note: Complements i.e. highly negative coeffs (post inversion) will be close to zero and thus regularised naturally
final_coefs = final_coefs.merge(
    final_coefs[['TO_ATTRIBUTE','Coefficient']].groupby(['TO_ATTRIBUTE']).min(), 
    on=['TO_ATTRIBUTE'], suffixes=("","_min")
)

final_coefs['Coefficient_minabs'] = abs(final_coefs['Coefficient_min'])
final_coefs['Coefficient_pos_shift'] = final_coefs['Coefficient'] + final_coefs['Coefficient_minabs']

final_coefs_adjusted_bayes = final_coefs.merge(
    final_coefs[['TO_ATTRIBUTE','Coefficient_pos_shift']].groupby(['TO_ATTRIBUTE']).sum(), 
    on=['TO_ATTRIBUTE'], suffixes=("","_sum")
)

final_coefs_adjusted_bayes.loc[:, 'Percent_Transfer'] = final_coefs_adjusted_bayes['Coefficient_pos_shift'] / final_coefs_adjusted_bayes['Coefficient_pos_shift_sum']
final_coefs_adjusted_bayes = final_coefs_adjusted_bayes[['TO_ATTRIBUTE','FROM_ATTRIBUTE','Percent_Transfer']].sort_values(['TO_ATTRIBUTE','Percent_Transfer'], ascending=False)


final_coefs_adjusted_bayes
# Out:
#                     TO_ATTRIBUTE                         FROM_ATTRIBUTE  \
# 1791  VRUCHTENDRANK - EIGEN MERK      OV.GAZEUSES - REGULAR - FERNANDES
# 1773  VRUCHTENDRANK - EIGEN MERK                      ENERGY - RED BULL
# 1788  VRUCHTENDRANK - EIGEN MERK       OV.GAZEUSES - LIGHT - EIGEN MERK
# 1795  VRUCHTENDRANK - EIGEN MERK  OV.VRUCHT.LIM. - REGULAR - EIGEN MERK
# 1770  VRUCHTENDRANK - EIGEN MERK     COLA - REGULAR - PEPSI & AO BRANDS
# ...                          ...                                    ...
# 10                   AO SEGMENTS                 ICE_TEA_BLACK - CARTON
# 13                   AO SEGMENTS                    ICE_TEA_GREEN - CAN
# 1                    AO SEGMENTS              COLA - LIGHT - EIGEN MERK
# 9                    AO SEGMENTS                    ICE_TEA_BLACK - CAN
# 39                   AO SEGMENTS              VRUCHTENDRANK - AO BRANDS
#
#       Percent_Transfer
# 1791              0.04
# 1773              0.04
# 1788              0.04
# 1795              0.04
# 1770              0.04
# ...                ...
# 10                0.01
# 13                0.01
# 1                 0.00
# 9                 0.00
# 39                0.00
#
# [1806 rows x 3 columns]

# %%
final_coefs_adjusted_bayes[['TO_ATTRIBUTE','FROM_ATTRIBUTE','Percent_Transfer']].sort_values(['TO_ATTRIBUTE','Percent_Transfer'], ascending=False).to_excel('./'+ANALYSIS_CATEGORY+' ATTR_SPECIFIC_BAYES_'+FOCUS_ATTRIBUTE_COLUMN+'_COEFS.xlsx', index=False)
final_scores_bayes.sort_values('MODEL_NAME', ascending=True).to_excel('./'+ANALYSIS_CATEGORY+' ATTR_SPECIFIC_BAYES_'+FOCUS_ATTRIBUTE_COLUMN+'_SCORES.xlsx', index=False)

# %% [markdown]
# YOU'RE DONE!!!
#
# Percent Transfers have been outputted to file that starts with your Category Name & Attribute of Focus in this directory
